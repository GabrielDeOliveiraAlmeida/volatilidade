# %% [markdown]
# ### Imports e Configurações

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
from scipy import stats

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import yfinance as yf

from datetime import datetime, timedelta, timezone

from sklearn.metrics import mean_squared_error as mse, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler, MinMaxScaler

from statsmodels.graphics.gofplots import qqplot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import kstest_normal,het_arch, acorr_ljungbox
from statsmodels.tsa.stattools import acf, q_stat, adfuller, kpss
from statsmodels.api import qqplot
from scipy.stats import probplot, moment, shapiro, jarque_bera

import pmdarima as pm

# %%
seed = 2022

# %%
pd.set_option('display.max_colwidth', None)

# %%
img_dir = os.path.join('..', 'img')

# %% [markdown]
# ### Funções Uteis

# %%
# Calcular a volatilidade realizada diaria
def realized_volatility_daily(series_log_return):
    n = len(series_log_return)
    return np.sqrt(np.sum(series_log_return**2)/(n - 1))
    # return np.sqrt(np.sum(series_log_return**2))
# Calcular a volatilidade realizada diaria
def realized_volatility(series_log_return):
    n = len(series_log_return)
    # return np.sqrt(np.sum(series_log_return**2)/(n - 1))
    return np.sqrt(np.sum(series_log_return**2))

def transform_volatility_to_scaler(scaler, tf_series):
    idx = tf_series.index
    output = pd.Series(scaler.transform(tf_series.values.reshape(-1,1))[:,0],
                       index=idx)
    return output

# %%
def RMSPE(y_true, y_pred):
    return np.sqrt(np.mean(np.square((y_true - y_pred) / y_true)))

def MSE(y_true, y_pred):
    return mse(y_true, y_pred)

def RMSE(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))  
     
def MAPE(y_true, y_pred): 
    return mean_absolute_percentage_error(y_true, y_pred)

# %%
def get_resid_garch(model):
    return model.std_resid
    # gm_resid = model.resid
    # gm_std = model.conditional_volatility
    # return gm_resid / gm_std

def pvalue_ljungbox(values):
    return acorr_ljungbox(values, lags=[10]).lb_pvalue.iloc[0]

def pvalue_het_arch(values):
    return het_arch(values)[1]

def pvalue_shapiro(values):
    return shapiro(values)[1]

# %%
perf_df = pd.DataFrame(columns=['Validation MSE', 'Validation RMSPE', 'Validation RMSE', "Validation MAPE"])
perf_train_df = pd.DataFrame(columns=['Training MSE', 'Training RMSE', "Training MAPE",'Validation MSE', 'Validation RMSE', "Validation MAPE"])
analysis_df = pd.DataFrame(columns=['AIC', 'BIC', 'LB', 'LB(r²)', 'ARCH', 'SW'])

def log_perf(y_true, y_pred, model_name):
    perf_df.loc[model_name] = [
        MSE(y_true, y_pred),
        RMSPE(y_true, y_pred), 
        RMSE(y_true, y_pred), 
        MAPE(y_true, y_pred)
    ]
    return perf_df

def log_perf_2(y_train_true, y_train_pred, y_true, y_pred, model_name):
    perf_train_df.loc[model_name] = [
        MSE(y_train_true, y_train_pred),
        RMSE(y_train_true, y_train_pred), 
        MAPE(y_train_true, y_train_pred),
        MSE(y_true, y_pred), 
        RMSE(y_true, y_pred), 
        MAPE(y_true, y_pred)
    ]
    return perf_train_df

def log_garch(model, model_name, isNormal = True):
    analysis_df.loc[model_name] = [
        model.aic,
        model.bic,
        pvalue_ljungbox(get_resid_garch(model)),
        pvalue_ljungbox(get_resid_garch(model)**2),
        pvalue_het_arch(get_resid_garch(model)),
        pvalue_shapiro(get_resid_garch(model)) if isNormal else np.nan
    ]
    return analysis_df

def reset_log_garch():
    analysis_df = pd.DataFrame(columns=[ 'AIC', 'BIC', 'LB', 'LB(r²)', 'ARCH', 'SW'])

    
def reset_log_perf():
    perf_df = pd.DataFrame(columns=['Validation MSE', 'Validation RMSPE', 'Validation RMSE', "MAPE"])

# %%
def correlogram(x, lags, title):
    
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 8))
    x.plot(ax=axes[0][0],grid= True, color='red')
    q_p = np.max(q_stat(acf(x,lags), len(x))[1])
    stats= f'ADF:{adfuller(x)[1]:.2f},\nQ-Stat:{q_p:.2f}'
    axes[0][0].text(x=.03, y=.85,s=stats, transform=axes[0][0].transAxes)
    
    #probability plot 
    probplot(x, plot=axes[0][1])
    mean, variance, skewness, kurtosis = moment(x, moment=[1, 2, 3, 4])
    stats1 = f'Mean: {mean:.2f}\nSD: {np.sqrt(variance):.2f}\nSkew: {skewness:.2f}\nKurtosis:{kurtosis:.2f}'
    axes[0][1].text(x=.02, y=.75,s=stats1, transform=axes[0][1].transAxes)
    
    #ACF and PACF plots
    plot_acf(x, lags=lags, zero=False, ax=axes[1][0],alpha=0.05,)
    plot_pacf(x, lags=lags, zero=False, ax=axes[1][1])
    axes[1][0].set_xlabel('Lag')
    axes[1][1].set_xlabel('Lag')
    fig.suptitle(title, fontsize=20)
    fig.tight_layout()
    fig.subplots_adjust(top=.9)

# %%
def viz_model(y_true, y_pred, model_name, save = False):
    sns.set_context("paper", font_scale=1.7)
    plt.rcParams["axes.grid"] = False

    with sns.axes_style("whitegrid"):
        plt.figure(figsize=(18,7))
        # plt.plot(x_val_scaled, color='gray',  ls=':',
        #         label=f"Scaled Current Daily Volatility")
        plt.plot(y_true, color='blue', lw=2, 
                label=f"Target Volatility")
        plt.plot(y_pred, color='orange', lw=2.5,
                label=f'Forecasted Volatility')

        plt.title(f'{model_name} \non Validation Data')
        plt.legend(loc='best', frameon=True)
        if(save):
                plt.savefig(os.path.join(img_dir, 'forecasted_volatility_' + model_name + '.png'), 
                        dpi=300, bbox_inches='tight')
        plt.show()

# %%
### GARCH FUNTIONS
def scale_tf_cond_vol(model_result):
    cond_vol = model_result.conditional_volatility
    scaler = MinMaxScaler()
    scaler = scaler.fit(cond_vol.values.reshape(-1,1))
    scaled_cond_vol = transform_volatility_to_scaler(scaler, cond_vol)
    return scaler, scaled_cond_vol

def viz_cond_vol(cond_vol_series, model_name):
    with sns.axes_style("darkgrid"):
        fig, ax = plt.subplots(figsize=(18,7))

        ax.plot(x_train_scaled, color='blue', lw=2,
                label=f'Scaled {INTERVAL_WINDOW}-Day Interval Daily Realized Volatility')
        ax.plot(cond_vol_series, color='orange', lw=2,
                label=f'Scaled {model_name} Estimated Conditional Volatility')
        ax.set_title('Training Set')
        plt.legend()
        plt.show();

def viz_only_cond_vol(cond_vol_series, model_name, save = False):
    with sns.axes_style("darkgrid"):
        fig, ax = plt.subplots(figsize=(18,7))

        ax.plot(cond_vol_series, color='orange', lw=2)
        plt.legend()
        if(save):
                plt.savefig(os.path.join(img_dir, 'cond_volatility_' + model_name + '.png'), 
                        dpi=300, bbox_inches='tight')
        plt.show();

# %% [markdown]
# ### Analise Exploratória

# %%
start = datetime(2018, 1, 1)
end = datetime(2023, 2, 1)
start_covid = datetime(2020,2,20)
end_covid = datetime(2021, 2, 28)

# %%
ticker_name = "^BVSP"
ticker = yf.Ticker(ticker_name)
df = ticker.history(start=start, 
                    end=end, 
                    interval="1d",
                    )

# %%
## Interpolar Time series (Preencher valores nulos)
date_range = pd.date_range(
    start=start, 
    end=end,
    freq='D'
  )
data = df.reset_index()
data['Date'] = data['Date'].astype('datetime64[ns]')
# data_aux = pd.DataFrame({'Date': date_range })
# data = pd.merge(data_aux, data, on='Date', how='left')
# data = data.set_index(["Date"], drop=True)  
# data.interpolate(method='linear', inplace=True)
# data = df.reset_index()
data['Date'] =data['Date'].apply(lambda x: x.replace(tzinfo=None))
# data_aux = pd.DataFrame({'Date': date_range })
# data = pd.merge(data_aux, data, on='Date', how='left')
data = data.set_index(["Date"], drop=True)  
# data.interpolate(method='linear', inplace=True)

# %%
data = data.dropna()

# %%
df = data

# %%
df
# Out:
#                          Open      High       Low     Close    Volume  \
# Date
# 2018-01-02 02:00:00   76403.0   77909.0   76403.0   77891.0   2880300
# 2018-01-03 02:00:00   77889.0   78414.0   77602.0   77995.0   3142200
# 2018-01-04 02:00:00   77998.0   79135.0   77998.0   78647.0   3486100
# 2018-01-05 02:00:00   78644.0   79071.0   78218.0   79071.0   2747100
# 2018-01-08 02:00:00   79070.0   79395.0   78631.0   79379.0   2550800
# ...                       ...       ...       ...       ...       ...
# 2023-01-25 03:00:00  113028.0  114386.0  111927.0  114195.0  11413000
# 2023-01-26 03:00:00  114271.0  114835.0  113591.0  114109.0  10920800
# 2023-01-27 03:00:00  114178.0  114191.0  112044.0  112502.0  10614500
# 2023-01-30 03:00:00  112319.0  112920.0  111824.0  111888.0  11272700
# 2023-01-31 03:00:00  112273.0  113581.0  112145.0  113532.0  12900200
#
#                      Dividends  Stock Splits
# Date
# 2018-01-02 02:00:00        0.0           0.0
# 2018-01-03 02:00:00        0.0           0.0
# 2018-01-04 02:00:00        0.0           0.0
# 2018-01-05 02:00:00        0.0           0.0
# 2018-01-08 02:00:00        0.0           0.0
# ...                        ...           ...
# 2023-01-25 03:00:00        0.0           0.0
# 2023-01-26 03:00:00        0.0           0.0
# 2023-01-27 03:00:00        0.0           0.0
# 2023-01-30 03:00:00        0.0           0.0
# 2023-01-31 03:00:00        0.0           0.0
#
# [1260 rows x 7 columns]

# %% [markdown]
# Inserir Variavies Dummy

# %%
df['covid'] = df.index.map(lambda date : 0 if date > start_covid and date < end_covid else 1)

# %%
with sns.axes_style("white"):
    fig, ax1 = plt.subplots(figsize=(15,7))
    ax1.plot(df.Close, color='blue', label='Preço Fechamento')  
    plt.xlabel('Intervalo de Data')
    plt.ylabel('Preço Fechamento')
    ax1.axvspan(start_covid,end_covid, facecolor='red', alpha=0.25)
    plt.show()

# %%
df['returns'] = 100 * df['Close'].pct_change().dropna()

# %% [markdown]
# LOG RETURNS FORMULA:
#
# $r_{t, t+i} = log(P_{t+i} / P_{t})$

# %%
df['log_returns'] = np.log(df['Close']/df['Close'].shift(1))

# %%
df.head(3)
# Out:
#                         Open     High      Low    Close   Volume  Dividends  \
# Date
# 2018-01-02 02:00:00  76403.0  77909.0  76403.0  77891.0  2880300        0.0
# 2018-01-03 02:00:00  77889.0  78414.0  77602.0  77995.0  3142200        0.0
# 2018-01-04 02:00:00  77998.0  79135.0  77998.0  78647.0  3486100        0.0
#
#                      Stock Splits  covid   returns  log_returns
# Date
# 2018-01-02 02:00:00           0.0      1       NaN          NaN
# 2018-01-03 02:00:00           0.0      1  0.133520     0.001334
# 2018-01-04 02:00:00           0.0      1  0.835951     0.008325

# %%
df.dropna(inplace=True)

# %%
df.head(3)
# Out:
#                         Open     High      Low    Close   Volume  Dividends  \
# Date
# 2018-01-03 02:00:00  77889.0  78414.0  77602.0  77995.0  3142200        0.0
# 2018-01-04 02:00:00  77998.0  79135.0  77998.0  78647.0  3486100        0.0
# 2018-01-05 02:00:00  78644.0  79071.0  78218.0  79071.0  2747100        0.0
#
#                      Stock Splits  covid   returns  log_returns
# Date
# 2018-01-03 02:00:00           0.0      1  0.133520     0.001334
# 2018-01-04 02:00:00           0.0      1  0.835951     0.008325
# 2018-01-05 02:00:00           0.0      1  0.539118     0.005377

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))

axes[0][0].plot(df['returns'], color='blue')
axes[0][0].set_title('Returns', fontsize=15)

sns.distplot(df['returns'],  color='blue',
             bins=50, ax=axes[0][1])
axes[0][1].set_title('Returns', fontsize=15)

axes[1][0].plot(df['log_returns'], color='orange')
axes[1][0].set_title('Log Returns', fontsize=15)

sns.distplot(df['log_returns'], norm_hist=True, fit=stats.norm, color='orange',
             bins=50, ax=axes[1][1])
axes[1][1].set_title('Log Returns', fontsize=15)
plt.tight_layout()
plt.savefig(os.path.join(img_dir, 'returns.jpg'), dpi=300, bbox_inches='tight')
fig.show();

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['returns'], color='blue')
plt.title('Returns')
plt.tight_layout()
plt.savefig(os.path.join(img_dir, 'simple-return.png'), dpi=300, bbox_inches='tight')
fig.show();

# %%
df['returns'].describe()
# Out:
# count    1259.000000
# mean        0.044648
# std         1.705459
# min       -14.779679
# 25%        -0.790934
# 50%         0.062529
# 75%         0.968740
# max        13.908215
# Name: returns, dtype: float64

# %%
stats.skew(df['returns'])
# Out:
# -0.9174751095867717

# %%
stats.kurtosis(df['returns'])
# Out:
# 15.61738008523476

# %%
df['log_returns'].describe()
# Out:
# count    1259.000000
# mean        0.000299
# std         0.017224
# min        -0.159930
# 25%        -0.007941
# 50%         0.000625
# 75%         0.009641
# max         0.130223
# Name: log_returns, dtype: float64

# %%
stats.skew(df['log_returns'])
# Out:
# -1.3638726564411485

# %%
stats.kurtosis(df['log_returns'])
# Out:
# 17.61083887504471

# %%
shapiro(df['returns'])
# Out:
# ShapiroResult(statistic=0.8738958239555359, pvalue=1.0187226189141378e-30)

# %% [markdown]
# #### **Returns/Log Returns Estacionariedade**

# %%
adfuller_results = adfuller(df['log_returns'])

print(f'ADF Statistic: {adfuller_results[0]}')
print(f'p-value: {adfuller_results[1]}')
print('Critical Values:')
for key, value in adfuller_results[4].items():
    print(f'{key}: {value:.4f}')
# Out:
# ADF Statistic: -12.003856416927121
# p-value: 3.298626469473426e-22
# Critical Values:
# 1%: -3.4356
# 5%: -2.8639
# 10%: -2.5680

# %%
# RETURNS
adfuller_results = adfuller(df['returns'])

print(f'ADF Statistic: {adfuller_results[0]}')
print(f'p-value: {adfuller_results[1]}')
print('Critical Values:')
for key, value in adfuller_results[4].items():
    print(f'{key}: {value:.4f}')
# Out:
# ADF Statistic: -11.168826061892032
# p-value: 2.6720930809323246e-20
# Critical Values:
# 1%: -3.4356
# 5%: -2.8639
# 10%: -2.5680

# %%
kpss_results = kpss(df['returns']);
print(kpss_results)
# Out:
# (0.051954162050138857, 0.1, 5, {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})
# C:\Users\gabriel\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %% [markdown]
# Para o nível de significancia com alpha igual a 0.05, o `p-value` de ambos, tanto o Retorno quanto do Log Retorno são menores que o alpha, logo tem-se evidencia suficiente para rejeitar a Hipotese nula.

# %% [markdown]
# ### Verificar Autocorrelação e Autocorrelação Parcial

# %%
plot_acf(df['returns'], lags=20,  title="Função de Autocorrelação (FAC) dos Retornos");
plt.tight_layout()
plt.savefig(os.path.join(img_dir, 'fac-return.jpg'), dpi=300, bbox_inches='tight')

# %%
plot_pacf(df['returns'], lags=20, title="Função de Autocorrelação Parcial (FACP) dos Retornos");
plt.tight_layout()
plt.savefig(os.path.join(img_dir, 'facp-return.jpg'), dpi=300, bbox_inches='tight')

# %%
acorr_ljungbox(df['returns'], lags=10)
# Out:
#       lb_stat     lb_pvalue
# 1   31.177437  2.354873e-08
# 2   35.153454  2.325544e-08
# 3   35.786854  8.307088e-08
# 4   36.988685  1.810997e-07
# 5   40.029609  1.472977e-07
# 6   56.630470  2.170259e-10
# 7   94.510279  1.462138e-17
# 8   94.673179  5.214613e-17
# 9   95.719431  1.151557e-16
# 10  96.013740  3.410450e-16

# %% [markdown]
# ### Volatiliade Realizada

# %%
INTERVAL_WINDOW = 30
n_future = 7

df['vol_current'] = df['log_returns'].rolling(window=INTERVAL_WINDOW)\
  .apply(realized_volatility_daily)

df['vol_future'] = df['log_returns']\
    .shift(-n_future)\
    .rolling(window=INTERVAL_WINDOW)\
      .apply(realized_volatility_daily)

# %%
df
# Out:
#                          Open      High       Low     Close    Volume  \
# Date
# 2018-01-03 02:00:00   77889.0   78414.0   77602.0   77995.0   3142200
# 2018-01-04 02:00:00   77998.0   79135.0   77998.0   78647.0   3486100
# 2018-01-05 02:00:00   78644.0   79071.0   78218.0   79071.0   2747100
# 2018-01-08 02:00:00   79070.0   79395.0   78631.0   79379.0   2550800
# 2018-01-09 02:00:00   79379.0   79415.0   78699.0   78864.0   3458600
# ...                       ...       ...       ...       ...       ...
# 2023-01-25 03:00:00  113028.0  114386.0  111927.0  114195.0  11413000
# 2023-01-26 03:00:00  114271.0  114835.0  113591.0  114109.0  10920800
# 2023-01-27 03:00:00  114178.0  114191.0  112044.0  112502.0  10614500
# 2023-01-30 03:00:00  112319.0  112920.0  111824.0  111888.0  11272700
# 2023-01-31 03:00:00  112273.0  113581.0  112145.0  113532.0  12900200
#
#                      Dividends  Stock Splits  covid   returns  log_returns  \
# Date
# 2018-01-03 02:00:00        0.0           0.0      1  0.133520     0.001334
# 2018-01-04 02:00:00        0.0           0.0      1  0.835951     0.008325
# 2018-01-05 02:00:00        0.0           0.0      1  0.539118     0.005377
# 2018-01-08 02:00:00        0.0           0.0      1  0.389523     0.003888
# 2018-01-09 02:00:00        0.0           0.0      1 -0.648786    -0.006509
# ...                        ...           ...    ...       ...          ...
# 2023-01-25 03:00:00        0.0           0.0      1  1.032488     0.010272
# 2023-01-26 03:00:00        0.0           0.0      1 -0.075310    -0.000753
# 2023-01-27 03:00:00        0.0           0.0      1 -1.408303    -0.014183
# 2023-01-30 03:00:00        0.0           0.0      1 -0.545768    -0.005473
# 2023-01-31 03:00:00        0.0           0.0      1  1.469326     0.014586
#
#                      vol_current  vol_future
# Date
# 2018-01-03 02:00:00          NaN         NaN
# 2018-01-04 02:00:00          NaN         NaN
# 2018-01-05 02:00:00          NaN         NaN
# 2018-01-08 02:00:00          NaN         NaN
# 2018-01-09 02:00:00          NaN         NaN
# ...                          ...         ...
# 2023-01-25 03:00:00     0.013759         NaN
# 2023-01-26 03:00:00     0.013759         NaN
# 2023-01-27 03:00:00     0.014008         NaN
# 2023-01-30 03:00:00     0.013949         NaN
# 2023-01-31 03:00:00     0.013877         NaN
#
# [1259 rows x 12 columns]

# %%
df.dropna(inplace=True)

# %%
plt.figure(figsize=(15,7))
plt.title('IBOVESP Preço Fechamento em BRL')
plt.plot(df['vol_current'])
plt.xlabel('Intervalo de Data')
plt.ylabel('Preço Fechamento')
# Out:
# Text(0, 0.5, 'Preço Fechamento')

# %% [markdown]
# ### Treino - Teste - Validação
#
# O dataset será dividido em:
# - Os 30 itens finais serão utilizados para teste final.
# - 1 ano inteiro para validação e ajustes do modelo
# - E o restante para treinamento

# %%
test_size = 30
val_size = 365

# INDICES
split_time_1 = len(df) - (val_size + test_size)
split_time_2 = len(df) - test_size

# PARA DIVIDIR O DATASET
train_idx = df.index[:split_time_1]
val_idx = df.index[split_time_1:split_time_2]
test_idx = df.index[split_time_2:]

# %%
print(f'Training \tFrom: {train_idx[0]} \tto: {train_idx[-1]} \t{len(train_idx)} days')
print(f'Validation \tFrom: {val_idx[0]} \tto: {val_idx[-1]} \t{len(val_idx)} days')
print(f'Test \t\tFrom: {test_idx[0]} \tto: {test_idx[-1]} \t{len(test_idx)} days')
# Out:
# Training 	From: 2018-02-16 02:00:00 	to: 2021-06-23 03:00:00 	828 days
# Validation 	From: 2021-06-24 03:00:00 	to: 2022-12-08 03:00:00 	365 days
# Test 		From: 2022-12-09 03:00:00 	to: 2023-01-20 03:00:00 	30 days

# %%
y_train = df['vol_future'][train_idx]
y_val = df['vol_future'][val_idx]
y_test = df['vol_future'][test_idx]

# %%
x_train = df['vol_current'][train_idx]
x_val = df['vol_current'][val_idx]
x_test = df['vol_current'][test_idx]

# %%
r_train = df['returns'][train_idx]
r_val = df['returns'][val_idx]
r_test = df['returns'][test_idx]

# %%
lr_train = df['log_returns'][train_idx]
lr_val = df['log_returns'][val_idx]
lr_test = df['log_returns'][test_idx]

# %%
covid_train = df['covid'][train_idx]
covid_val = df['covid'][val_idx]

# %% [markdown]
# ### Normalizar os dados

# %%
scaler_vol = MinMaxScaler()

# FIT SCALER TO CURRENT REALIZED VOLATILITY IN TRAINING
scaler_vol = scaler_vol.fit(x_train.values.reshape(-1,1))

# %%
# TRANSFORM TRAINING CURRENT & FUTURE VOLATILITIES 
x_train_scaled = transform_volatility_to_scaler(scaler_vol, x_train)
y_train_scaled = transform_volatility_to_scaler(scaler_vol, y_train)

# TRANSFORMING VALIDATION CURRENT & FUTURE VOLATILITIES
x_val_scaled = transform_volatility_to_scaler(scaler_vol, x_val)
y_val_scaled = transform_volatility_to_scaler(scaler_vol, y_val)

# TRANSFORMING TEST CURRENT & FUTURE VOLATILITIES
x_test_scaled = transform_volatility_to_scaler(scaler_vol, x_test)
y_test_scaled = transform_volatility_to_scaler(scaler_vol, y_test)

# %%
plt.figure(figsize=(20,6))

plt.plot(df.log_returns, color='gray', label='Daily Log Returns', alpha=0.4)

plt.plot(x_train, color='blue', label='Scaled Training Volatility')
plt.plot(x_val, color='orange', label='Scaled Validation Volatility')
plt.plot(x_test, color='green', label='Scaled Test Volatility')

plt.plot()
plt.title(f'TRAINING / VALIDATION / TEST SPLITS', 
          fontsize=15)
plt.legend(frameon=True)
plt.savefig(os.path.join(img_dir, 'train_val_test.jpg'), dpi=300, bbox_inches='tight')
plt.show();

# %%
def expading_window_forecast_garch(arch_model, use_covid = False):
    size = len(val_idx)
    rolling_forecasts = []
    idx = df.index
    # Set de validação
    for i in range(0, size, 1):
    # Pegar os valores anteriores a esse step
        idx = val_idx[i]
        train = df.returns[:idx]
        covid = df.covid[:idx]
        # treinar o modelo até esse step
        if use_covid:
            model = arch_model(train, covid)
        else: 
            model = arch_model(train)
        model_fit = model.fit(disp='off')
        # fazer a predição com n_future 
        if use_covid:
            values = model_fit.forecast(horizon=1, x=[df.covid[idx]],
                             reindex=False).variance.iloc[0]
        else:
            values = model_fit.forecast(horizon=1,
                             reindex=False).variance.iloc[0]
        for value in values:
            rolling_forecasts.append(value)
    values_forecast = []
    for i in range(size):
        values_forecast.append(rolling_forecasts[i]**.5)
    return pd.Series(values_forecast, index=val_idx)

# %% [markdown]
# ### ARMA

# %%
from pmdarima.arima import auto_arima

# %%
arma = auto_arima(
  r_train,
  d=0,
  max_q=12,
  max_p=12,
  trace=True,
  seasonal=False,
  error_action='ignore',
  suppress_warnings=True,
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=3333.696, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=3383.895, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=3352.496, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=3356.850, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=3352.924, Time=0.12 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=3350.875, Time=0.17 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=3344.691, Time=0.44 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=3335.463, Time=0.51 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=3353.123, Time=0.07 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=3345.096, Time=0.28 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=3340.639, Time=0.22 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=3335.859, Time=0.56 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=3334.224, Time=0.61 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0]
# Total fit time: 3.385 seconds

# %%
arma.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  828
# Model:               SARIMAX(2, 0, 2)   Log Likelihood               -1661.848
# Date:                Thu, 30 Mar 2023   AIC                           3333.696
# Time:                        16:31:25   BIC                           3357.291
# Sample:                             0   HQIC                          3342.746
#                                 - 828
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6035      0.032    -50.791      0.000      -1.665      -1.542
# ar.L2         -0.7665      0.030    -25.382      0.000      -0.826      -0.707
# ma.L1          1.4478      0.038     37.903      0.000       1.373       1.523
# ma.L2          0.5938      0.038     15.767      0.000       0.520       0.668
# sigma2         3.2413      0.059     55.033      0.000       3.126       3.357
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):              8689.79
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                            -1.06
# Prob(H) (two-sided):                  0.92   Kurtosis:                        18.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
resid_arma = arma.resid()

# %%
acorr_ljungbox(resid_arma, lags=[10])
# Out:
#       lb_stat  lb_pvalue
# 10  23.299284   0.009694

# %%
het_arch(resid_arma, nlags=10 )
# Out:
# (323.1003536408408,
#  2.0113498704772693e-63,
#  52.685829805368755,
#  2.4464425508670517e-81)

# %%
plot_acf(resid_arma,lags=20, title="");
        #   title='Função de Autocorrelação (FAC) do quadrado dos Retornos');
plt.tight_layout()

# %%
plot_acf(resid_arma**2,lags=20, title="");
        #   title='Função de Autocorrelação (FAC) do quadrado dos Retornos');
plt.tight_layout()

# %% [markdown]
# ### GARCH MODELS

# %% [markdown]
# some Util links
# - https://www.oreilly.com/library/view/machine-learning-for/9781492085249/ch04.html
# - https://users.metu.edu.tr/home402/ozancan/wwwhome/ARCHGARCHTutorial.html
# - https://bibliotecadigital.fgv.br/dspace/bitstream/handle/10438/10014/TD%20313%20-%20CEQEF%2003%20-%20Marcos%20Vinicio%20Wink%20Junior%20e%20%20Pedro%20Valls.pdf?sequence=1
# - https://repositorio.ufc.br/bitstream/riufc/39729/1/2018_tcc_wlalves.pdf
# - file:///C:/Users/Gabriel/Downloads/paulo%20thomaz.pdf

# %%
plot_acf(r_train**2,lags=20, title="");
        #   title='Função de Autocorrelação (FAC) do quadrado dos Retornos');
plt.tight_layout()
plt.savefig(os.path.join(img_dir, 'fac-return-squared.jpg'), dpi=300, bbox_inches='tight')

# %%
plot_pacf(r_train**2, lags=20, title="")
        #   title='Função de Autocorrelação Parcial (FACP) do quadrado dos Retornos\n(Treinamento)');
plt.tight_layout()
plt.savefig(os.path.join(img_dir, 'facp-return-squared.jpg'), dpi=300, bbox_inches='tight')

# %% [markdown]
# Verifica-se pelo quadrado dos retornos que o modelo ARCH é adaquado

# %% [markdown]
# ### GARCH

# %%
from arch import arch_model

# %% [markdown]
# ARMA-GARCH

# %%
arma_gm_11 = arch_model(resid_arma, p=1, q=1)
result_arma_gm_11 = arma_gm_11.fit(disp='off')
arma_gm_12 = arch_model(resid_arma, p=1, q=2)
result_arma_gm_12 = arma_gm_12.fit(disp='off')
arma_gm_21 = arch_model(resid_arma, p=2, q=1)
result_arma_gm_21 = arma_gm_21.fit(disp='off')
arma_gm_22 = arch_model(resid_arma, p=2, q=2)
result_arma_gm_22 = arma_gm_22.fit(disp='off')

log_garch(result_arma_gm_11, "ARMA-GARCH (1,1) - Normal")
log_garch(result_arma_gm_12, "ARMA-GARCH (1,2) - Normal")
log_garch(result_arma_gm_21, "ARMA-GARCH (2,1) - Normal")
log_garch(result_arma_gm_22, "ARMA-GARCH (2,2) - Normal")
# Out:
#                                    AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal  2958.891056  2987.205135  0.001076  0.130804
#
#                                ARCH            SW
# ARMA-GARCH (1,1) - Normal  0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal  0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal  0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal  0.134286  5.433234e-09

# %%
arma_gm_student_11 = arch_model(resid_arma, p=1, q=1)
result_arma_gm_student_11 = arma_gm_student_11.fit(disp='off')
arma_gm_student_12 = arch_model(resid_arma, p=1, q=2)
result_arma_gm_student_12 = arma_gm_student_12.fit(disp='off')
arma_gm_student_21 = arch_model(resid_arma, p=2, q=1)
result_arma_gm_student_21 = arma_gm_student_21.fit(disp='off')
arma_gm_student_22 = arch_model(resid_arma, p=2, q=2)
result_arma_gm_student_22 = arma_gm_student_22.fit(disp='off')

log_garch(result_arma_gm_student_11, "ARMA-GARCH (1,1) - Student", False)
log_garch(result_arma_gm_student_12, "ARMA-GARCH (1,2) - Student", False)
log_garch(result_arma_gm_student_21, "ARMA-GARCH (2,1) - Student", False)
log_garch(result_arma_gm_student_22, "ARMA-GARCH (2,2) - Student", False)
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN

# %% [markdown]
# ARX-GARCH

# %%
arxgm_11 = arch_model(r_train, x=covid_train, mean="ARX", p=1, q=1, dist="normal")
result_arxgm_11 = arxgm_11.fit(disp='off')
arxgm_12 = arch_model(r_train, x=covid_train, mean="ARX", p=1, q=2, dist="normal")
result_arxgm_12 = arxgm_12.fit(disp='off')
arxgm_21 = arch_model(r_train,x=covid_train, mean="ARX", p=2, q=1, dist="normal")
result_arxgm_21 = arxgm_21.fit(disp='off')
arxgm_22 = arch_model(r_train, x=covid_train, mean="ARX",p=2, q=2, dist="normal")
result_arxgm_22 = arxgm_22.fit(disp='off')
arxgm_10 = arch_model(r_train, x=covid_train, mean="ARX", p=1, q=0, dist="normal")
result_arxgm_10 = arxgm_10.fit(disp='off')

# %%
result_arxgm_11
# Out:
#                           AR-X - GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                      -0.002
# Mean Model:                      AR-X   Adj. R-squared:                 -0.003
# Vol Model:                      GARCH   Log-Likelihood:               -1467.21
# Distribution:                  Normal   AIC:                           2944.43
# Method:            Maximum Likelihood   BIC:                           2968.02
#                                         No. Observations:                  828
# Date:                Thu, Mar 30 2023   Df Residuals:                      826
# Time:                        16:31:28   Df Model:                            2
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# Const          0.1636      0.121      1.353      0.176 [-7.335e-02,  0.401]
# covid         -0.0565      0.128     -0.443      0.658    [ -0.307,  0.194]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.1086  4.448e-02      2.442  1.462e-02 [2.143e-02,  0.196]
# alpha[1]       0.1209  3.668e-02      3.295  9.825e-04 [4.899e-02,  0.193]
# beta[1]        0.8340  4.235e-02     19.692  2.537e-86   [  0.751,  0.917]
# ==========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x1b65d971de0

# %%
log_garch(result_arxgm_11, "ARX-GARCH (1,1) - Normal")
log_garch(result_arxgm_12, "ARX-GARCH (1,2) - Normal")
log_garch(result_arxgm_21, "ARX-GARCH (2,1) - Normal")
log_garch(result_arxgm_22, "ARX-GARCH (2,2) - Normal")
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09

# %%
arxgm_student_11 = arch_model(y=r_train, x=covid_train, mean="ARX", p=1, q=1, dist="StudentsT", vol="GARCH")
result_arxgm_student_11 = arxgm_student_11.fit(disp='off')
arxgm_student_12 = arch_model(r_train, x=covid_train, mean="ARX", p=1, q=2, dist="StudentsT")
result_arxgm_student_12 = arxgm_student_12.fit(disp='off')
arxgm_student_21 = arch_model(r_train,x=covid_train, mean="ARX", p=2, q=1, dist="StudentsT")
result_arxgm_student_21 = arxgm_student_21.fit(disp='off')
arxgm_student_22 = arch_model(r_train, x=covid_train, mean="ARX",p=2, q=2, dist="StudentsT")
result_arxgm_student_22 = arxgm_student_22.fit(disp='off')
arxgm_student_10 = arch_model(r_train, x=covid_train, mean="ARX", p=1, q=0, dist="StudentsT")
result_arxgm_student_10 = arxgm_student_10.fit(disp='off')

# %%
result_arxgm_student_11
# Out:
#                              AR-X - GARCH Model Results
# ====================================================================================
# Dep. Variable:                      returns   R-squared:                      -0.002
# Mean Model:                            AR-X   Adj. R-squared:                 -0.003
# Vol Model:                            GARCH   Log-Likelihood:               -1452.40
# Distribution:      Standardized Student's t   AIC:                           2916.81
# Method:                  Maximum Likelihood   BIC:                           2945.12
#                                               No. Observations:                  828
# Date:                      Thu, Mar 30 2023   Df Residuals:                      826
# Time:                              16:31:28   Df Model:                            2
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# Const          0.1604      0.109      1.465      0.143 [-5.421e-02,  0.375]
# covid         -0.0361      0.118     -0.305      0.761    [ -0.268,  0.196]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0929  3.607e-02      2.575  1.003e-02 [2.217e-02,  0.164]
# alpha[1]       0.1125  2.729e-02      4.124  3.726e-05 [5.904e-02,  0.166]
# beta[1]        0.8478  3.326e-02     25.492 2.419e-143   [  0.783,  0.913]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             8.6493      2.392      3.616  2.994e-04 [  3.961, 13.338]
# ========================================================================
#
# Covariance estimator: robust
# ARCHModelResult, id: 0x1b65d970130

# %%
log_garch(result_arxgm_student_11, "ARX-GARCH (1,1) - Student")
log_garch(result_arxgm_student_12, "ARX-GARCH (1,2) - Student")
log_garch(result_arxgm_student_21, "ARX-GARCH (2,1) - Student")
log_garch(result_arxgm_student_22, "ARX-GARCH (2,2) - Student")
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09

# %%
arxgm_student_11_preds = expading_window_forecast_garch(lambda train, covid: arch_model(train, x=covid, mean="ARX", p=1, q=1, dist="StudentsT"), True )
scaler_garch_student_11, scaled_arx_cond_vol_student_11 = scale_tf_cond_vol(result_arxgm_student_11)
arxgm_student_11_preds_scaled = transform_volatility_to_scaler(scaler_garch_student_11, arxgm_student_11_preds)
log_perf(y_val_scaled, arxgm_student_11_preds_scaled,'ARX-GARCH(1,1) - Student')
# Out:
#                           Validation MSE  Validation RMSPE  Validation RMSE  \
# ARX-GARCH(1,1) - Student        0.001033          0.490845         0.032143
#
#                           Validation MAPE
# ARX-GARCH(1,1) - Student         0.323179

# %%
viz_model(y_val_scaled, arxgm_student_11_preds_scaled, 'GARCH(1,1) - Normal')

# %% [markdown]
# ### GArch

# %%
gm_11 = arch_model(r_train, p=1, q=1, dist="normal")
result_11 = gm_11.fit(disp='off')
gm_12 = arch_model(r_train, p=1, q=2, dist="normal")
result_12 = gm_12.fit(disp='off')
gm_21 = arch_model(r_train, p=2, q=1, dist="normal")
result_21 = gm_21.fit(disp='off')
gm_22 = arch_model(r_train, p=2, q=2, dist="normal")
result_22 = gm_22.fit(disp='off')
gm_10 = arch_model(r_train, p=1, q=0, dist="normal")
result_10 = gm_10.fit(disp='off')

# %%
het_arch(result_11.std_resid)
# Out:
# (13.430085265120779,
#  0.20060906244258284,
#  1.3470648865268364,
#  0.20084459811747968)

# %%
acorr_ljungbox(result_11.std_resid**2, lags=[10])
# Out:
#       lb_stat  lb_pvalue
# 10  13.714166   0.186433

# %%
result_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -1467.33
# Distribution:                  Normal   AIC:                           2942.66
# Method:            Maximum Likelihood   BIC:                           2961.54
#                                         No. Observations:                  828
# Date:                Thu, Mar 30 2023   Df Residuals:                      827
# Time:                        16:31:44   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.1169  4.323e-02      2.705  6.839e-03 [3.219e-02,  0.202]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.1078  4.336e-02      2.486  1.291e-02 [2.282e-02,  0.193]
# alpha[1]       0.1195  3.478e-02      3.435  5.920e-04 [5.131e-02,  0.188]
# beta[1]        0.8356  4.024e-02     20.768  8.462e-96   [  0.757,  0.914]
# ==========================================================================
#
# Covariance estimator: robust
# """

# %%
log_garch(result_11, "GARCH (1,1) - Normal")
log_garch(result_12, "GARCH (1,2) - Normal")
log_garch(result_21, "GARCH (2,1) - Normal")
log_garch(result_22, "GARCH (2,2) - Normal")
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09

# %% [markdown]
# Utilizando nivel de significande de 0.05, nenhum dos coefieficientes para os modelos (1,2), (2,1), (2,2) parecem ser estatisticamente significante, já que o os seus p-values `P > |t|` são todos maiores que 0.05. diferente do GARCH (1,1)

# %% [markdown]
# É possivel verificar que que pelo test `Shapiro Wilk (SW)`, `p-value` é menor que 0.05, portanto é rejeita-se a hipotese nula e assim, temos evidencia suficiente para dizer que não segue uma distribuição normal, o que é comum para series financeiras, porém o modelo garch permite setar a distribuição como T Student ,

# %%
gm_student_11 = arch_model(r_train, p=1, q=1, dist="StudentsT")
result_student_11 = gm_student_11.fit(disp='off')
gm_student_22 = arch_model(r_train, p=2, q=2, dist="StudentsT")
result_student_22 = gm_student_22.fit(disp='off')
gm_student_12 = arch_model(r_train, p=1, q=2, dist="StudentsT")
result_student_12 = gm_student_12.fit(disp='off')
gm_student_21 = arch_model(r_train, p=2, q=1, dist="StudentsT")
result_student_21 = gm_student_21.fit(disp='off')

# %%
result_student_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                         Constant Mean - GARCH Model Results
# ====================================================================================
# Dep. Variable:                      returns   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -1452.46
# Distribution:      Standardized Student's t   AIC:                           2914.91
# Method:                  Maximum Likelihood   BIC:                           2938.51
#                                               No. Observations:                  828
# Date:                      Thu, Mar 30 2023   Df Residuals:                      827
# Time:                              16:31:44   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.1309  4.184e-02      3.129  1.757e-03 [4.889e-02,  0.213]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0925  3.588e-02      2.579  9.906e-03 [2.221e-02,  0.163]
# alpha[1]       0.1122  2.711e-02      4.140  3.474e-05 [5.910e-02,  0.165]
# beta[1]        0.8483  3.302e-02     25.688 1.572e-145   [  0.784,  0.913]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             8.6317      2.379      3.628  2.858e-04 [  3.968, 13.295]
# ========================================================================
#
# Covariance estimator: robust
# """

# %%
log_garch(result_student_11, "GARCH (1,1) - Student", False)
log_garch(result_student_12, "GARCH (1,2) - Student", False)
log_garch(result_student_21, "GARCH (2,1) - Student", False)
log_garch(result_student_22, "GARCH (2,2) - Student", False)
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
# GARCH (1,1) - Student       2914.914872  2938.509938  0.107009  0.159954
# GARCH (1,2) - Student       2916.913605  2945.227684  0.107574  0.157085
# GARCH (2,1) - Student       2916.914873  2945.228952  0.107000  0.159851
# GARCH (2,2) - Student       2918.348017  2951.381109  0.108143  0.060966
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09
# GARCH (1,1) - Student       0.176542           NaN
# GARCH (1,2) - Student       0.173175           NaN
# GARCH (2,1) - Student       0.176447           NaN
# GARCH (2,2) - Student       0.073588           NaN

# %%
scaler_garch_student_11, scaled_cond_vol_student_11 = scale_tf_cond_vol(result_student_11)
viz_only_cond_vol(scaled_cond_vol_student_11, 'GARCH(1,1) - t de Student', True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
scaler_garch_11, scaled_cond_vol_11 = scale_tf_cond_vol(result_11)
viz_cond_vol(scaled_cond_vol_11, 'GARCH(1,1)')

# %% [markdown]
# ### Expanding Window Forecasting
#
# Será dada a previsão para os próximo dias futuros `n_future = 14` e assim deve-se reajustar o modelo para cada passo no tempo.

# %%
gm_11_preds = expading_window_forecast_garch(lambda train: arch_model(train, vol='GARCH', p=1, q=1))

# %%
gm_11_preds_scaled = transform_volatility_to_scaler(scaler_garch_11, gm_11_preds)

# %%
viz_model(y_val_scaled, gm_11_preds_scaled, 'GARCH(1,1) - Normal')

# %%
log_perf(y_val_scaled, gm_11_preds_scaled,'GARCH(1,1) - Normal')
# Out:
#                           Validation MSE  Validation RMSPE  Validation RMSE  \
# ARX-GARCH(1,1) - Student        0.001033          0.490845         0.032143
# GARCH(1,1) - Normal             0.001125          0.508638         0.033547
#
#                           Validation MAPE
# ARX-GARCH(1,1) - Student         0.323179
# GARCH(1,1) - Normal              0.337772

# %%
log_perf(y_val_scaled, gm_11_preds_scaled,'GARCH(1,1) - Normal')
# Out:
#                           Validation MSE  Validation RMSPE  Validation RMSE  \
# ARX-GARCH(1,1) - Student        0.001033          0.490845         0.032143
# GARCH(1,1) - Normal             0.001125          0.508638         0.033547
#
#                           Validation MAPE
# ARX-GARCH(1,1) - Student         0.323179
# GARCH(1,1) - Normal              0.337772

# %%
gm_student_11_preds = expading_window_forecast_garch(lambda train: arch_model(train, vol='GARCH', p=1, q=1, dist="StudentsT") )
scaler_garch_student_11, scaled_cond_vol_student_11 = scale_tf_cond_vol(result_student_11)
gm_student_11_preds_scaled = transform_volatility_to_scaler(scaler_garch_student_11, gm_student_11_preds)
log_perf(y_val_scaled, gm_student_11_preds_scaled,'GARCH(1,1) - Student')
# Out:
#                           Validation MSE  Validation RMSPE  Validation RMSE  \
# ARX-GARCH(1,1) - Student        0.001033          0.490845         0.032143
# GARCH(1,1) - Normal             0.001125          0.508638         0.033547
# GARCH(1,1) - Student            0.001019          0.492070         0.031925
#
#                           Validation MAPE
# ARX-GARCH(1,1) - Student         0.323179
# GARCH(1,1) - Normal              0.337772
# GARCH(1,1) - Student             0.322151

# %%
viz_model(y_val_scaled, gm_student_11_preds_scaled, 'GARCH(1,1) - t de Student', True)

# %% [markdown]
# ### Garch Model with asymmetric shock response

# %%
gjr_gm_11 = arch_model(r_train, p=1, q=1, o=1, vol='GARCH')
result_gjr_gm_11 = gjr_gm_11.fit(disp='off')
gjr_gm_22 = arch_model(r_train, p=2, q=2, o=1, vol='GARCH')
result_gjr_gm_22 = gjr_gm_22.fit(disp='off')
gjr_gm_21 = arch_model(r_train, p=2, q=1, o=1, vol='GARCH')
result_gjr_gm_21 = gjr_gm_21.fit(disp='off')
gjr_gm_12 = arch_model(r_train, p=1, q=2, o=1, vol='GARCH')
result_gjr_gm_12 = gjr_gm_12.fit(disp='off')

# %%
result_gjr_gm_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                    Constant Mean - GJR-GARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                  GJR-GARCH   Log-Likelihood:               -1460.55
# Distribution:                  Normal   AIC:                           2931.11
# Method:            Maximum Likelihood   BIC:                           2954.70
#                                         No. Observations:                  828
# Date:                Thu, Mar 30 2023   Df Residuals:                      827
# Time:                        16:32:11   Df Model:                            1
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# mu             0.0860  4.451e-02      1.932  5.338e-02 [-1.254e-03,  0.173]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.1139  4.951e-02      2.301  2.137e-02    [1.690e-02,  0.211]
# alpha[1]       0.0350  2.551e-02      1.373      0.170 [-1.498e-02,8.502e-02]
# gamma[1]       0.1355  5.786e-02      2.341  1.921e-02    [2.207e-02,  0.249]
# beta[1]        0.8448  4.766e-02     17.725  2.694e-70      [  0.751,  0.938]
# =============================================================================
#
# Covariance estimator: robust
# """

# %%
log_garch(result_gjr_gm_11, "GJR-GARCH (1,1) - Normal")
log_garch(result_gjr_gm_12, "GJR-GARCH (1,2) - Normal")
log_garch(result_gjr_gm_21, "GJR-GARCH (2,1) - Normal")
log_garch(result_gjr_gm_22, "GJR-GARCH (2,2) - Normal")
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
# GARCH (1,1) - Student       2914.914872  2938.509938  0.107009  0.159954
# GARCH (1,2) - Student       2916.913605  2945.227684  0.107574  0.157085
# GARCH (2,1) - Student       2916.914873  2945.228952  0.107000  0.159851
# GARCH (2,2) - Student       2918.348017  2951.381109  0.108143  0.060966
# GJR-GARCH (1,1) - Normal    2931.109234  2954.704300  0.174097  0.794192
# GJR-GARCH (1,2) - Normal    2933.095707  2961.409786  0.175171  0.787613
# GJR-GARCH (2,1) - Normal    2933.001375  2961.315454  0.173090  0.822698
# GJR-GARCH (2,2) - Normal    2934.939319  2967.972411  0.175642  0.817618
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09
# GARCH (1,1) - Student       0.176542           NaN
# GARCH (1,2) - Student       0.173175           NaN
# GARCH (2,1) - Student       0.176447           NaN
# GARCH (2,2) - Student       0.073588           NaN
# GJR-GARCH (1,1) - Normal    0.780108  7.166018e-08
# GJR-GARCH (1,2) - Normal    0.772652  7.312322e-08
# GJR-GARCH (2,1) - Normal    0.812796  7.222418e-08
# GJR-GARCH (2,2) - Normal    0.806809  7.593295e-08

# %%
gjr_gm_student_11 = arch_model(r_train, p=1, q=1, o=1, vol='GARCH', dist='StudentsT')
result_gjr_gm_student_11 = gjr_gm_student_11.fit(disp='off')
gjr_gm_student_22 = arch_model(r_train, p=2, q=2, o=1, vol='GARCH', dist='StudentsT')
result_gjr_gm_student_22 = gjr_gm_student_22.fit(disp='off')
gjr_gm_student_21 = arch_model(r_train, p=2, q=1, o=1, vol='GARCH', dist='StudentsT')
result_gjr_gm_student_21 = gjr_gm_student_21.fit(disp='off')
gjr_gm_student_12 = arch_model(r_train, p=1, q=2, o=1, vol='GARCH', dist='StudentsT')
result_gjr_gm_student_12 = gjr_gm_student_12.fit(disp='off')

# %%
result_gjr_gm_student_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - GJR-GARCH Model Results
# ====================================================================================
# Dep. Variable:                      returns   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                        GJR-GARCH   Log-Likelihood:               -1448.29
# Distribution:      Standardized Student's t   AIC:                           2908.57
# Method:                  Maximum Likelihood   BIC:                           2936.89
#                                               No. Observations:                  828
# Date:                      Thu, Mar 30 2023   Df Residuals:                      827
# Time:                              16:32:11   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.1054  4.341e-02      2.428  1.519e-02 [2.030e-02,  0.190]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.1003  4.307e-02      2.329  1.984e-02    [1.591e-02,  0.185]
# alpha[1]       0.0390  2.393e-02      1.629      0.103 [-7.928e-03,8.588e-02]
# gamma[1]       0.1208  5.109e-02      2.364  1.806e-02    [2.066e-02,  0.221]
# beta[1]        0.8527  4.067e-02     20.964  1.397e-97      [  0.773,  0.932]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             9.1040      2.583      3.524  4.252e-04 [  4.041, 14.168]
# ========================================================================
#
# Covariance estimator: robust
# """

# %%
log_garch(result_gjr_gm_student_11, "GJR-GARCH (1,1) - Student", False)
log_garch(result_gjr_gm_student_12, "GJR-GARCH (1,2) - Student", False)
log_garch(result_gjr_gm_student_21, "GJR-GARCH (2,1) - Student", False)
log_garch(result_gjr_gm_student_22, "GJR-GARCH (2,2) - Student", False)
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
# GARCH (1,1) - Student       2914.914872  2938.509938  0.107009  0.159954
# GARCH (1,2) - Student       2916.913605  2945.227684  0.107574  0.157085
# GARCH (2,1) - Student       2916.914873  2945.228952  0.107000  0.159851
# GARCH (2,2) - Student       2918.348017  2951.381109  0.108143  0.060966
# GJR-GARCH (1,1) - Normal    2931.109234  2954.704300  0.174097  0.794192
# GJR-GARCH (1,2) - Normal    2933.095707  2961.409786  0.175171  0.787613
# GJR-GARCH (2,1) - Normal    2933.001375  2961.315454  0.173090  0.822698
# GJR-GARCH (2,2) - Normal    2934.939319  2967.972411  0.175642  0.817618
# GJR-GARCH (1,1) - Student   2908.573761  2936.887840  0.163843  0.768576
# GJR-GARCH (1,2) - Student   2910.573761  2943.606853  0.163845  0.768566
# GJR-GARCH (2,1) - Student   2910.267123  2943.300215  0.162084  0.825080
# GJR-GARCH (2,2) - Student   2912.267124  2950.019229  0.162108  0.825128
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09
# GARCH (1,1) - Student       0.176542           NaN
# GARCH (1,2) - Student       0.173175           NaN
# GARCH (2,1) - Student       0.176447           NaN
# GARCH (2,2) - Student       0.073588           NaN
# GJR-GARCH (1,1) - Normal    0.780108  7.166018e-08
# GJR-GARCH (1,2) - Normal    0.772652  7.312322e-08
# GJR-GARCH (2,1) - Normal    0.812796  7.222418e-08
# GJR-GARCH (2,2) - Normal    0.806809  7.593295e-08
# GJR-GARCH (1,1) - Student   0.754948           NaN
# GJR-GARCH (1,2) - Student   0.754939           NaN
# GJR-GARCH (2,1) - Student   0.818899           NaN
# GJR-GARCH (2,2) - Student   0.818944           NaN

# %% [markdown]
# ### TARCH

# %%
np.random.seed(seed)
t_gm_11 = arch_model(r_train, p=1, o=1, q=1, power=1.0, dist='normal')
result_t_gm_11 = t_gm_11.fit(disp='off')
t_gm_22 = arch_model(r_train, p=2, o=1, q=2, power=1.0, dist='normal')
result_t_gm_22 = t_gm_22.fit(disp='off')
t_gm_21 = arch_model(r_train, p=2, o=1, q=1, power=1.0, dist='normal')
result_t_gm_21 = t_gm_21.fit(disp='off')
t_gm_12 = arch_model(r_train, p=1, o=1, q=2, power=1.0, dist='normal')
result_t_gm_12 = t_gm_12.fit(disp='off')

# %%
result_t_gm_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                   Constant Mean - TARCH/ZARCH Model Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                TARCH/ZARCH   Log-Likelihood:               -1454.01
# Distribution:                  Normal   AIC:                           2918.02
# Method:            Maximum Likelihood   BIC:                           2941.62
#                                         No. Observations:                  828
# Date:                Thu, Mar 30 2023   Df Residuals:                      827
# Time:                        16:32:12   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu             0.0925  6.985e-04    132.360      0.000 [9.109e-02,9.382e-02]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0886  3.671e-02      2.412  1.585e-02    [1.661e-02,  0.161]
# alpha[1]       0.0459  2.750e-02      1.669  9.507e-02 [-7.996e-03,9.981e-02]
# gamma[1]       0.1652  4.990e-02      3.310  9.346e-04    [6.735e-02,  0.263]
# beta[1]        0.8386  4.696e-02     17.856  2.578e-71      [  0.747,  0.931]
# =============================================================================
#
# Covariance estimator: robust
# """

# %%
log_garch(result_t_gm_11, "TARCH (1,1) - Normal")
log_garch(result_t_gm_12, "TARCH (1,2) - Normal")
log_garch(result_t_gm_21, "TARCH (2,1) - Normal")
log_garch(result_t_gm_22, "TARCH (2,2) - Normal")
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
# GARCH (1,1) - Student       2914.914872  2938.509938  0.107009  0.159954
# GARCH (1,2) - Student       2916.913605  2945.227684  0.107574  0.157085
# GARCH (2,1) - Student       2916.914873  2945.228952  0.107000  0.159851
# GARCH (2,2) - Student       2918.348017  2951.381109  0.108143  0.060966
# GJR-GARCH (1,1) - Normal    2931.109234  2954.704300  0.174097  0.794192
# GJR-GARCH (1,2) - Normal    2933.095707  2961.409786  0.175171  0.787613
# GJR-GARCH (2,1) - Normal    2933.001375  2961.315454  0.173090  0.822698
# GJR-GARCH (2,2) - Normal    2934.939319  2967.972411  0.175642  0.817618
# GJR-GARCH (1,1) - Student   2908.573761  2936.887840  0.163843  0.768576
# GJR-GARCH (1,2) - Student   2910.573761  2943.606853  0.163845  0.768566
# GJR-GARCH (2,1) - Student   2910.267123  2943.300215  0.162084  0.825080
# GJR-GARCH (2,2) - Student   2912.267124  2950.019229  0.162108  0.825128
# TARCH (1,1) - Normal        2918.023387  2941.618453  0.180972  0.845775
# TARCH (1,2) - Normal        2919.752827  2948.066906  0.181832  0.805716
# TARCH (2,1) - Normal        2920.019789  2948.333868  0.180977  0.851294
# TARCH (2,2) - Normal        2921.701051  2954.734143  0.182213  0.827671
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09
# GARCH (1,1) - Student       0.176542           NaN
# GARCH (1,2) - Student       0.173175           NaN
# GARCH (2,1) - Student       0.176447           NaN
# GARCH (2,2) - Student       0.073588           NaN
# GJR-GARCH (1,1) - Normal    0.780108  7.166018e-08
# GJR-GARCH (1,2) - Normal    0.772652  7.312322e-08
# GJR-GARCH (2,1) - Normal    0.812796  7.222418e-08
# GJR-GARCH (2,2) - Normal    0.806809  7.593295e-08
# GJR-GARCH (1,1) - Student   0.754948           NaN
# GJR-GARCH (1,2) - Student   0.754939           NaN
# GJR-GARCH (2,1) - Student   0.818899           NaN
# GJR-GARCH (2,2) - Student   0.818944           NaN
# TARCH (1,1) - Normal        0.838066  2.092695e-06
# TARCH (1,2) - Normal        0.796787  2.467922e-06
# TARCH (2,1) - Normal        0.843871  2.078985e-06
# TARCH (2,2) - Normal        0.820068  2.465229e-06

# %%
np.random.seed(seed)
t_gm_student_11 = arch_model(r_train, p=1, o=1, q=1, power=1.0, dist='StudentsT')
result_t_gm_student_11 = t_gm_student_11.fit(disp='off')
t_gm_student_22 = arch_model(r_train, p=2, o=1, q=2, power=1.0, dist='StudentsT')
result_t_gm_student_22 = t_gm_student_22.fit(disp='off')
t_gm_student_21 = arch_model(r_train, p=2, o=1, q=1, power=1.0, dist='StudentsT')
result_t_gm_student_21 = t_gm_student_21.fit(disp='off')
t_gm_student_12 = arch_model(r_train, p=1, o=1, q=2, power=1.0, dist='StudentsT')
result_t_gm_student_12 = t_gm_student_12.fit(disp='off')

# %%
log_garch(result_t_gm_student_11, "TARCH (1,1) - Student", False)
log_garch(result_t_gm_student_12, "TARCH (1,2) - Student", False)
log_garch(result_t_gm_student_21, "TARCH (2,1) - Student", False)
log_garch(result_t_gm_student_11, "TARCH (2,2) - Student", False)
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
# GARCH (1,1) - Student       2914.914872  2938.509938  0.107009  0.159954
# GARCH (1,2) - Student       2916.913605  2945.227684  0.107574  0.157085
# GARCH (2,1) - Student       2916.914873  2945.228952  0.107000  0.159851
# GARCH (2,2) - Student       2918.348017  2951.381109  0.108143  0.060966
# GJR-GARCH (1,1) - Normal    2931.109234  2954.704300  0.174097  0.794192
# GJR-GARCH (1,2) - Normal    2933.095707  2961.409786  0.175171  0.787613
# GJR-GARCH (2,1) - Normal    2933.001375  2961.315454  0.173090  0.822698
# GJR-GARCH (2,2) - Normal    2934.939319  2967.972411  0.175642  0.817618
# GJR-GARCH (1,1) - Student   2908.573761  2936.887840  0.163843  0.768576
# GJR-GARCH (1,2) - Student   2910.573761  2943.606853  0.163845  0.768566
# GJR-GARCH (2,1) - Student   2910.267123  2943.300215  0.162084  0.825080
# GJR-GARCH (2,2) - Student   2912.267124  2950.019229  0.162108  0.825128
# TARCH (1,1) - Normal        2918.023387  2941.618453  0.180972  0.845775
# TARCH (1,2) - Normal        2919.752827  2948.066906  0.181832  0.805716
# TARCH (2,1) - Normal        2920.019789  2948.333868  0.180977  0.851294
# TARCH (2,2) - Normal        2921.701051  2954.734143  0.182213  0.827671
# TARCH (1,1) - Student       2903.215157  2931.529236  0.164011  0.815734
# TARCH (1,2) - Student       2905.215157  2938.248250  0.164011  0.815738
# TARCH (2,1) - Student       2905.094883  2938.127975  0.163642  0.851403
# TARCH (2,2) - Student       2903.215157  2931.529236  0.164011  0.815734
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09
# GARCH (1,1) - Student       0.176542           NaN
# GARCH (1,2) - Student       0.173175           NaN
# GARCH (2,1) - Student       0.176447           NaN
# GARCH (2,2) - Student       0.073588           NaN
# GJR-GARCH (1,1) - Normal    0.780108  7.166018e-08
# GJR-GARCH (1,2) - Normal    0.772652  7.312322e-08
# GJR-GARCH (2,1) - Normal    0.812796  7.222418e-08
# GJR-GARCH (2,2) - Normal    0.806809  7.593295e-08
# GJR-GARCH (1,1) - Student   0.754948           NaN
# GJR-GARCH (1,2) - Student   0.754939           NaN
# GJR-GARCH (2,1) - Student   0.818899           NaN
# GJR-GARCH (2,2) - Student   0.818944           NaN
# TARCH (1,1) - Normal        0.838066  2.092695e-06
# TARCH (1,2) - Normal        0.796787  2.467922e-06
# TARCH (2,1) - Normal        0.843871  2.078985e-06
# TARCH (2,2) - Normal        0.820068  2.465229e-06
# TARCH (1,1) - Student       0.809651           NaN
# TARCH (1,2) - Student       0.809654           NaN
# TARCH (2,1) - Student       0.846602           NaN
# TARCH (2,2) - Student       0.809651           NaN

# %% [markdown]
# ### EGARCH

# %%
np.random.seed(seed)
e_gm_11 = arch_model(r_train, vol='EGARCH', p=1, o=1, q=1, power=1.0, dist='normal')
result_e_gm_11 = e_gm_11.fit(disp='off')
e_gm_22 = arch_model(r_train, vol='EGARCH', p=2, o=1, q=2, power=1.0, dist='normal')
result_e_gm_22 = e_gm_22.fit(disp='off')
e_gm_21 = arch_model(r_train, vol='EGARCH', p=2, o=1, q=1, power=1.0, dist='normal')
result_e_gm_21 = e_gm_21.fit(disp='off')
e_gm_12 = arch_model(r_train, vol='EGARCH', p=1, o=1, q=2, power=1.0, dist='normal')
result_e_gm_12 = e_gm_12.fit(disp='off')

# %%
log_garch(result_e_gm_11, "EGARCH (1,1) - Normal")
log_garch(result_e_gm_12, "EGARCH (1,2) - Normal")
log_garch(result_e_gm_21, "EGARCH (2,1) - Normal")
log_garch(result_e_gm_22, "EGARCH (2,2) - Normal")
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
# GARCH (1,1) - Student       2914.914872  2938.509938  0.107009  0.159954
# GARCH (1,2) - Student       2916.913605  2945.227684  0.107574  0.157085
# GARCH (2,1) - Student       2916.914873  2945.228952  0.107000  0.159851
# GARCH (2,2) - Student       2918.348017  2951.381109  0.108143  0.060966
# GJR-GARCH (1,1) - Normal    2931.109234  2954.704300  0.174097  0.794192
# GJR-GARCH (1,2) - Normal    2933.095707  2961.409786  0.175171  0.787613
# GJR-GARCH (2,1) - Normal    2933.001375  2961.315454  0.173090  0.822698
# GJR-GARCH (2,2) - Normal    2934.939319  2967.972411  0.175642  0.817618
# GJR-GARCH (1,1) - Student   2908.573761  2936.887840  0.163843  0.768576
# GJR-GARCH (1,2) - Student   2910.573761  2943.606853  0.163845  0.768566
# GJR-GARCH (2,1) - Student   2910.267123  2943.300215  0.162084  0.825080
# GJR-GARCH (2,2) - Student   2912.267124  2950.019229  0.162108  0.825128
# TARCH (1,1) - Normal        2918.023387  2941.618453  0.180972  0.845775
# TARCH (1,2) - Normal        2919.752827  2948.066906  0.181832  0.805716
# TARCH (2,1) - Normal        2920.019789  2948.333868  0.180977  0.851294
# TARCH (2,2) - Normal        2921.701051  2954.734143  0.182213  0.827671
# TARCH (1,1) - Student       2903.215157  2931.529236  0.164011  0.815734
# TARCH (1,2) - Student       2905.215157  2938.248250  0.164011  0.815738
# TARCH (2,1) - Student       2905.094883  2938.127975  0.163642  0.851403
# TARCH (2,2) - Student       2903.215157  2931.529236  0.164011  0.815734
# EGARCH (1,1) - Normal       2921.122813  2944.717879  0.145097  0.865494
# EGARCH (1,2) - Normal       2923.120901  2951.434980  0.145390  0.861974
# EGARCH (2,1) - Normal       2922.870409  2951.184488  0.144220  0.904045
# EGARCH (2,2) - Normal       2924.769753  2957.802845  0.146921  0.898268
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,2) - Student  0.134286           NaN
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09
# GARCH (1,1) - Student       0.176542           NaN
# GARCH (1,2) - Student       0.173175           NaN
# GARCH (2,1) - Student       0.176447           NaN
# GARCH (2,2) - Student       0.073588           NaN
# GJR-GARCH (1,1) - Normal    0.780108  7.166018e-08
# GJR-GARCH (1,2) - Normal    0.772652  7.312322e-08
# GJR-GARCH (2,1) - Normal    0.812796  7.222418e-08
# GJR-GARCH (2,2) - Normal    0.806809  7.593295e-08
# GJR-GARCH (1,1) - Student   0.754948           NaN
# GJR-GARCH (1,2) - Student   0.754939           NaN
# GJR-GARCH (2,1) - Student   0.818899           NaN
# GJR-GARCH (2,2) - Student   0.818944           NaN
# TARCH (1,1) - Normal        0.838066  2.092695e-06
# TARCH (1,2) - Normal        0.796787  2.467922e-06
# TARCH (2,1) - Normal        0.843871  2.078985e-06
# TARCH (2,2) - Normal        0.820068  2.465229e-06
# TARCH (1,1) - Student       0.809651           NaN
# TARCH (1,2) - Student       0.809654           NaN
# TARCH (2,1) - Student       0.846602           NaN
# TARCH (2,2) - Student       0.809651           NaN
# EGARCH (1,1) - Normal       0.855512  7.295346e-07
# EGARCH (1,2) - Normal       0.851901  7.360204e-07
# EGARCH (2,1) - Normal       0.896916  7.933897e-07
# EGARCH (2,2) - Normal       0.891455  8.852354e-07

# %%
np.random.seed(seed)
e_gm_student_11 = arch_model(r_train, vol='EGARCH', p=1, o=1, q=1, power=1.0, dist='StudentsT')
result_e_gm_student_11 = e_gm_student_11.fit(disp='off')
e_gm_student_22 = arch_model(r_train, p=2, o=1, q=2, power=1.0, dist='StudentsT')
result_e_gm_student_22 = e_gm_student_22.fit(disp='off')
e_gm_student_21 = arch_model(r_train, p=2, o=1, q=1, power=1.0, dist='StudentsT')
result_e_gm_student_21 = e_gm_student_21.fit(disp='off')
e_gm_student_12 = arch_model(r_train, p=1, o=1, q=2, power=1.0, dist='StudentsT')
result_e_gm_student_12 = e_gm_student_12.fit(disp='off')

# %%
log_garch(result_e_gm_student_11, "EGARCH (1,1) - Student", False)
log_garch(result_e_gm_student_12, "EGARCH (1,2) - Student", False)
log_garch(result_e_gm_student_21, "EGARCH (2,1) - Student", False)
log_garch(result_e_gm_student_11, "EGARCH (2,2) - Student", False)
# Out:
#                                     AIC          BIC        LB    LB(r²)  \
# ARMA-GARCH (1,1) - Normal   2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Normal   2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Normal   2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Normal   2958.891056  2987.205135  0.001076  0.130804
# ARMA-GARCH (1,1) - Student  2955.018482  2973.894535  0.001143  0.172702
# ARMA-GARCH (1,2) - Student  2956.936895  2980.531961  0.001177  0.171417
# ARMA-GARCH (2,1) - Student  2957.018483  2980.613549  0.001143  0.172726
# ARMA-GARCH (2,2) - Student  2958.891056  2987.205135  0.001076  0.130804
# ARX-GARCH (1,1) - Normal    2944.427580  2968.022646  0.116877  0.212197
# ARX-GARCH (1,2) - Normal    2946.330742  2974.644821  0.119590  0.194295
# ARX-GARCH (2,1) - Normal    2946.427580  2974.741659  0.116877  0.212201
# ARX-GARCH (2,2) - Normal    2948.330743  2981.363835  0.119584  0.194282
# ARX-GARCH (1,1) - Student   2916.806632  2945.120710  0.110850  0.168205
# ARX-GARCH (1,2) - Student   2918.806105  2951.839197  0.111195  0.166316
# ARX-GARCH (2,1) - Student   2918.806631  2951.839723  0.110846  0.168138
# ARX-GARCH (2,2) - Student   2920.272865  2958.024970  0.111112  0.065704
# GARCH (1,1) - Normal        2942.663685  2961.539738  0.109785  0.186433
# GARCH (1,2) - Normal        2944.566569  2968.161635  0.112693  0.169252
# GARCH (2,1) - Normal        2944.663685  2968.258751  0.109784  0.186422
# GARCH (2,2) - Normal        2946.566569  2974.880648  0.112691  0.169232
# GARCH (1,1) - Student       2914.914872  2938.509938  0.107009  0.159954
# GARCH (1,2) - Student       2916.913605  2945.227684  0.107574  0.157085
# GARCH (2,1) - Student       2916.914873  2945.228952  0.107000  0.159851
# GARCH (2,2) - Student       2918.348017  2951.381109  0.108143  0.060966
# GJR-GARCH (1,1) - Normal    2931.109234  2954.704300  0.174097  0.794192
# GJR-GARCH (1,2) - Normal    2933.095707  2961.409786  0.175171  0.787613
# GJR-GARCH (2,1) - Normal    2933.001375  2961.315454  0.173090  0.822698
# GJR-GARCH (2,2) - Normal    2934.939319  2967.972411  0.175642  0.817618
# GJR-GARCH (1,1) - Student   2908.573761  2936.887840  0.163843  0.768576
# GJR-GARCH (1,2) - Student   2910.573761  2943.606853  0.163845  0.768566
# GJR-GARCH (2,1) - Student   2910.267123  2943.300215  0.162084  0.825080
# GJR-GARCH (2,2) - Student   2912.267124  2950.019229  0.162108  0.825128
# TARCH (1,1) - Normal        2918.023387  2941.618453  0.180972  0.845775
# TARCH (1,2) - Normal        2919.752827  2948.066906  0.181832  0.805716
# TARCH (2,1) - Normal        2920.019789  2948.333868  0.180977  0.851294
# TARCH (2,2) - Normal        2921.701051  2954.734143  0.182213  0.827671
# TARCH (1,1) - Student       2903.215157  2931.529236  0.164011  0.815734
# TARCH (1,2) - Student       2905.215157  2938.248250  0.164011  0.815738
# TARCH (2,1) - Student       2905.094883  2938.127975  0.163642  0.851403
# TARCH (2,2) - Student       2903.215157  2931.529236  0.164011  0.815734
# EGARCH (1,1) - Normal       2921.122813  2944.717879  0.145097  0.865494
# EGARCH (1,2) - Normal       2923.120901  2951.434980  0.145390  0.861974
# EGARCH (2,1) - Normal       2922.870409  2951.184488  0.144220  0.904045
# EGARCH (2,2) - Normal       2924.769753  2957.802845  0.146921  0.898268
# EGARCH (1,1) - Student      2904.832728  2933.146807  0.132057  0.838134
# EGARCH (1,2) - Student      2905.215157  2938.248250  0.164011  0.815738
# EGARCH (2,1) - Student      2905.094883  2938.127975  0.163642  0.851403
# EGARCH (2,2) - Student      2904.832728  2933.146807  0.132057  0.838134
#
#                                 ARCH            SW
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2
# GARCH (1,1) - Student       0.176542           NaN
# TARCH (1,1) - Normal        0.838066  2.092695e-06
# GJR-GARCH (2,1) - Student   0.818899           NaN
# GJR-GARCH (1,2) - Student   0.754939           NaN
# EGARCH (1,1) - Normal       0.855512  7.295346e-07
# ARX-GARCH (1,1) - Student   0.185992  2.021588e-09
# GARCH (1,2) - Student       0.173175           NaN
# GARCH (2,1) - Student       0.176447           NaN
# TARCH (1,2) - Normal        0.796787  2.467922e-06
# TARCH (2,1) - Normal        0.843871  2.078985e-06
# GJR-GARCH (2,2) - Student   0.818944           NaN
# EGARCH (2,1) - Normal       0.896916  7.933897e-07
# GARCH (2,2) - Student       0.073588           NaN
# EGARCH (1,2) - Normal       0.851901  7.360204e-07
# ARX-GARCH (1,2) - Student   0.183775  2.021402e-09
# ARX-GARCH (2,1) - Student   0.185930  2.021029e-09
# GJR-GARCH (1,1) - Normal    0.780108  7.166018e-08
# TARCH (2,2) - Normal        0.820068  2.465229e-06
# EGARCH (2,2) - Normal       0.891455  8.852354e-07
# ARX-GARCH (2,2) - Student   0.079405  1.339102e-09
# GJR-GARCH (2,1) - Normal    0.812796  7.222418e-08
# GJR-GARCH (1,2) - Normal    0.772652  7.312322e-08
# GARCH (1,1) - Normal        0.200609  2.239904e-09
# GJR-GARCH (2,2) - Normal    0.806809  7.593295e-08
# ARX-GARCH (1,1) - Normal    0.227284  2.316096e-09
# GARCH (1,2) - Normal        0.180824  2.200102e-09
# GARCH (2,1) - Normal        0.200599  2.241424e-09
# ARMA-GARCH (1,1) - Student  0.175508           NaN
# ARMA-GARCH (1,1) - Normal   0.175508  6.316040e-09
# ARX-GARCH (1,2) - Normal    0.206766  2.274656e-09
# ARX-GARCH (2,1) - Normal    0.227288  2.316541e-09
# GARCH (2,2) - Normal        0.180806  2.201425e-09
# ARMA-GARCH (1,2) - Student  0.172916           NaN
# ARMA-GARCH (1,2) - Normal   0.172916  6.960452e-09
# ARMA-GARCH (2,1) - Student  0.175530           NaN
# ARMA-GARCH (2,1) - Normal   0.175530  6.320434e-09
# ARX-GARCH (2,2) - Normal    0.206749  2.274342e-09
# ARMA-GARCH (2,2) - Normal   0.134286  5.433234e-09
# ARMA-GARCH (2,2) - Student  0.134286           NaN

# %%
qqplot(get_resid_garch(result_student_11), line='r');

# %% [markdown]
# ### SALVAR Modelos GARCH

# %%
modelToSave = arch_model(df['returns'], vol='GARCH', p=1, q=1, dist="StudentsT").fit(disp='off')
scaler_garch_to_save, scaled_cond_vol_to_save = scale_tf_cond_vol(modelToSave)
df['garch11_student'] = scaled_cond_vol_to_save

# %% [markdown]
# ### REDES NEURAIS

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import backend as K
from decimal import Decimal

# %%
# CONVERT AN SERIES TO MATRIX DATASET
def windowed_dataset(x_series, y_series, lookback_window):
    dataX, dataY = [], []
    for i in range((lookback_window-1), len(x_series)):
        start_idx = x_series.index[i-lookback_window+1]
        end_idx = x_series.index[i]
        a = x_series[start_idx:end_idx].values
        dataX.append(a)
        dataY.append(y_series[end_idx])

    return np.array(dataX), np.array(dataY)

# %%
def scale(scaler, y_series):
    scaled = pd.Series(scaler.transform(y_series.values.reshape(-1,1))[:, 0],
                       index=y_series.index)
    return scaled

# %%
# Forecast RNN
def forecast(model, range_idx, n_past):
    location_index = df.vol_current.index.get_loc(range_idx[0])
    end_idx = range_idx[-1]
    start_idx = df.vol_current.iloc[location_index - n_past + 1:].index[0]
    mat_X, _ = windowed_dataset(df.vol_current[start_idx:end_idx], 
                                df.vol_future[range_idx], n_past)
    preds = pd.Series(model.predict(mat_X)[:, 0],
                      index=range_idx)

    return preds

def forecast_train(model, range_idx, mat_X):
    preds = pd.Series(model.predict(mat_X)[:, 0],
                      index=range_idx)
    return preds

# %%
def viz_train_val_metrics(model_hist):
    with sns.axes_style("white"):
        fig, ax = plt.subplots(figsize=(15,6))

        # PLOT MSE - LEFT Y-AXIS
        # TRAINING
        ln11 = ax.plot(range(len(model_hist.history['loss'])), 
                    model_hist.history['loss'], color='lightblue',
                    label='Training MSE', lw=2)
        # VALIDATION
        ln12 = ax.plot(range(len(model_hist.history['loss'])),
                    model_hist.history['val_loss'], color='darkblue',
                    label='Validation MSE', lw=2)
        ax.set_xlabel('Epoch')
        ax.set_ylabel('MSE')

        # PLOT RMSE - RIGHT Y-AXIS
        ax2 = ax.twinx()
        ln21 = ax2.plot(range(len(model_hist.history['loss'])), 
                    model_hist.history['rmspe'], color='pink', lw=2,
                    label='Training RMSPE')
        ln22 = ax2.plot(range(len(model_hist.history['loss'])), 
                    model_hist.history['val_rmspe'], color='red', lw=2,
                    label='Validation RMSPE')
        ax2.set_ylabel('RMSPE')

        # COMBINING LALBELS FOR 4 LINES INTO 1 LEGEND
        lns = ln11 + ln12 + ln21 + ln22
        labs = [l.get_label() for l in lns]
        ax.legend(lns, labs, loc='best')

        ax.set_title('Training vs. Validation Learning Curves')
        plt.show();

# %%
# from keras import backend

def rmspe(y_true, y_pred):
    '''
    Compute Root Mean Square Percentage Error between two arrays
    that can be used as metrics for NN during training
    '''
    # return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))
    # if not K.is_tensor(y_pred):
    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.cast(y_true, y_pred.dtype)
    diff = K.mean(K.abs((y_pred - y_true)) / K.mean(K.clip(K.abs(y_true),
                                                           K.epsilon(),
                                                           None)))
    return 100. * K.mean(diff)

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 30
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)
])
# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')


snn_2.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe])
snn_2.summary()

snn_2_res = snn_2.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                      callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_2_preds = forecast(snn_2, val_idx, n_past=n_past)
snn_2_preds_scaled = scale(scaler_vol, snn_2_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_2_preds_scaled,
         f"Simple LR Fully Connected NN, 16 units, {len(snn_2_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                496
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 997us/step
#                                                                     Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30        0.000378
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30        0.000527
#
#                                                                     Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30          0.650405
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30          0.419211
#
#                                                                     Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30         0.019431
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30         0.022946
#
#                                                                     Validation MAPE
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30         0.280260
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30         0.290597

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 30
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_3 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
    #  tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])

# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

snn_3.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe]
              )
snn_3.summary()
snn_3_res = snn_3.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                       callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_3_preds = forecast(snn_3, val_idx, n_past)
snn_3_preds_scaled = scale(scaler_vol, snn_3_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_3_preds_scaled,
         f"Simple LR Fully Connected NN, 32 units, {len(snn_3_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                992
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 997us/step
#                                                                     Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30        0.000541
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30        0.000508
#
#                                                                     Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30          0.346437
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30          0.620033
#
#                                                                     Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30         0.023268
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30         0.022542
#
#                                                                     Validation MAPE
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30         0.258679
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30         0.320705

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 60
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_4 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
    #  tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

snn_4.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe]
              )
snn_4.summary()
snn_4_res = snn_4.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                       callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_4_preds = forecast(snn_4, val_idx, n_past)
snn_4_preds_scaled = scale(scaler_vol, snn_4_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_4_preds_scaled,
         f"Simple LR Fully Connected NN, 16 units, {len(snn_4_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                976
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 993
# Trainable params: 993
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 1ms/step
#                                                                     Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30        0.000541
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30        0.000508
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60        0.000560
#
#                                                                     Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30          0.346437
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30          0.620033
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60          0.439869
#
#                                                                     Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30         0.023268
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30         0.022542
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60         0.023667
#
#                                                                     Validation MAPE
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30         0.258679
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30         0.320705
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60         0.287162

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 60
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_5 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
    #  tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

snn_5.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe]
              )
snn_5.summary()
snn_5_res = snn_5.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                       callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_5_preds = forecast(snn_5, val_idx, n_past)
snn_5_preds_scaled = scale(scaler_vol, snn_5_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_5_preds_scaled,
         f"Simple LR Fully Connected NN, 32 units, {len(snn_5_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1952
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,985
# Trainable params: 1,985
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 997us/step
#                                                                     Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30        0.000541
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30        0.000508
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60        0.000560
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60        0.000565
#
#                                                                     Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30          0.346437
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30          0.620033
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60          0.439869
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60          0.638238
#
#                                                                     Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30         0.023268
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30         0.022542
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60         0.023667
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60         0.023762
#
#                                                                     Validation MAPE
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30         0.258679
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30         0.320705
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60         0.287162
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60         0.336168

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 30
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_6 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
     tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])

early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

snn_6.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe]
              )
snn_6.summary()
snn_6_res = snn_6.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                      callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_6_preds = forecast(snn_6, val_idx, n_past)
snn_6_preds_scaled = scale(scaler_vol, snn_6_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_6_preds_scaled,
         f"Simple LR Fully Connected NN, 16 units, Dropout (10%) {len(snn_5_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                496
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 1ms/step
#                                                                                   Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                      0.000541
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                      0.000508
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                      0.000560
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                      0.000565
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30        0.000726
#
#                                                                                   Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                        0.346437
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                        0.620033
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                        0.439869
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                        0.638238
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30          0.928352
#
#                                                                                   Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.023268
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.022542
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.023667
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.023762
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.026943
#
#                                                                                   Validation MAPE
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.258679
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.320705
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.287162
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.336168
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.369457

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 30
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_7 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
     tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])

early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

snn_7.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe]
              )
snn_7.summary()
snn_7_res = snn_7.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                      callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_7_preds = forecast(snn_7, val_idx, n_past)
snn_7_preds_scaled = scale(scaler_vol, snn_7_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_7_preds_scaled,
         f"Simple LR Fully Connected NN, 32 units, Dropout (10%) {len(snn_5_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                992
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 997us/step
#                                                                                   Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                      0.000541
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                      0.000508
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                      0.000560
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                      0.000565
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30        0.000726
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30        0.000487
#
#                                                                                   Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                        0.346437
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                        0.620033
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                        0.439869
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                        0.638238
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30          0.928352
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30          0.600846
#
#                                                                                   Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.023268
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.022542
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.023667
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.023762
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.026943
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30         0.022058
#
#                                                                                   Validation MAPE
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.258679
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.320705
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.287162
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.336168
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.369457
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30         0.290822

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 60
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_8 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
     tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])

early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

snn_8.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe]
              )
snn_8.summary()
snn_8_res = snn_8.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                      callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_8_preds = forecast(snn_8, val_idx, n_past)
snn_8_preds_scaled = scale(scaler_vol, snn_8_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_8_preds_scaled,
         f"Simple LR Fully Connected NN, 16 units, Dropout (10%) {len(snn_5_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                976
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 993
# Trainable params: 993
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 907us/step
#                                                                                   Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                      0.000541
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                      0.000508
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                      0.000560
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                      0.000565
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30        0.000726
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30        0.000487
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60        0.001985
#
#                                                                                   Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                        0.346437
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                        0.620033
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                        0.439869
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                        0.638238
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30          0.928352
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30          0.600846
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60          0.630061
#
#                                                                                   Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.023268
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.022542
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.023667
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.023762
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.026943
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30         0.022058
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60         0.044551
#
#                                                                                   Validation MAPE
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.258679
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.320705
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.287162
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.336168
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.369457
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30         0.290822
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60         0.395819

# %%
# CLEARING ANY INTERNAL VARIABLES TO PREVENT MODELS
# FROM IMPACTING LATER VERSIONS OF THEMSELVES
tf.keras.backend.clear_session()
np.random.seed(seed)

n_past = 60
batch_size = 64

mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

snn_9 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, input_shape=[n_past], activation='relu'),                         
    #  tf.keras.layers.Dense(32, activation='relu'),
     tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])

early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

snn_9.compile(loss='mse', 
              optimizer='adam', 
              metrics=[rmspe]
              )
snn_9.summary()
snn_9_res = snn_9.fit(mat_X_train, mat_y_train, epochs=1000,
                      validation_split=0.2,
                      callbacks=[early_stopping_cb],
                      verbose=0, batch_size=batch_size, 
                      shuffle=True)
snn_9_preds = forecast(snn_9, val_idx, n_past)
snn_9_preds_scaled = scale(scaler_vol, snn_9_preds)
# APPEND METRICS OUTPUTS TO perf_df DATAFRAME
log_perf(y_val_scaled, snn_9_preds_scaled,
         f"Simple LR Fully Connected NN, 32 units, Dropout (10%) {len(snn_5_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1952
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,985
# Trainable params: 1,985
# Non-trainable params: 0
# _________________________________________________________________
# 12/12 [==============================] - 0s 907us/step
#                                                                                   Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30
1000
# 10/10 [==============================] - 0s 18ms/step - loss: 1.9663e-05 - rmspe: 0.0022 - val_loss: 4.4877e-06 - val_rmspe: 0.0017
# Epoch 281/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 1.9277e-05 - rmspe: 0.0021 - val_loss: 6.9133e-06 - val_rmspe: 0.0022
# Epoch 282/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 2.0650e-05 - rmspe: 0.0024 - val_loss: 5.2566e-06 - val_rmspe: 0.0018
# Epoch 283/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 2.0065e-05 - rmspe: 0.0023 - val_loss: 4.7841e-06 - val_rmspe: 0.0018
# Epoch 284/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 1.9411e-05 - rmspe: 0.0022 - val_loss: 5.9649e-06 - val_rmspe: 0.0020
# Epoch 285/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 2.0002e-05 - rmspe: 0.0023 - val_loss: 5.6573e-06 - val_rmspe: 0.0019
# Epoch 286/1000
# 10/10 [==============================] - 0s 19ms/step - loss: 1.9993e-05 - rmspe: 0.0023 - val_loss: 5.3445e-06 - val_rmspe: 0.0019
# 12/12 [==============================] - 0s 4ms/step
#                                                                                   Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                      0.000541
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                      0.000508
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                      0.000560
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                      0.000565
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30        0.000726
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30        0.000487
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60        0.001985
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=60        0.001181
# LSTM 1 layer, 16 units, 358/1000 epochs, n_past=30                                      0.000520
# LSTM 1 layer, 32 units, 286/1000 epochs, n_past=30                                      0.000315
#
#                                                                                   Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                        0.346437
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                        0.620033
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                        0.439869
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                        0.638238
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30          0.928352
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30          0.600846
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60          0.630061
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=60          0.660237
# LSTM 1 layer, 16 units, 358/1000 epochs, n_past=30                                        0.572693
# LSTM 1 layer, 32 units, 286/1000 epochs, n_past=30                                        0.405335
#
#                                                                                   Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.023268
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.022542
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.023667
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.023762
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.026943
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30         0.022058
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60         0.044551
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=60         0.034371
# LSTM 1 layer, 16 units, 358/1000 epochs, n_past=30                                       0.022813
# LSTM 1 layer, 32 units, 286/1000 epochs, n_past=30                                       0.017756
#
#                                                                                   Validation MAPE
# Simple LR Fully Connected NN, 16 units, 186/1000 epochs, n_past=30                       0.258679
# Simple LR Fully Connected NN, 32 units, 261/1000 epochs, n_past=30                       0.320705
# Simple LR Fully Connected NN, 16 units, 151/1000 epochs, n_past=60                       0.287162
# Simple LR Fully Connected NN, 32 units, 204/1000 epochs, n_past=60                       0.336168
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=30         0.369457
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=30         0.290822
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 204/1000 epochs, n_past=60         0.395819
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 204/1000 epochs, n_past=60         0.368706
# LSTM 1 layer, 16 units, 358/1000 epochs, n_past=30                                       0.336607
# LSTM 1 layer, 32 units, 286/1000 epochs, n_past=30                                       0.248406

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 60
batch_size = 64
mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

lstm_3 = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), 
                           input_shape=[None]),                            
    # ADDING 1 LSTM LAYER
    tf.keras.layers.LSTM(16),
    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_3.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])
# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

lstm_3.summary()
lstm_3_res = lstm_3.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, 
                        shuffle=False,
                        batch_size=batch_size, 
                        epochs=1000)
lstm_3_preds = forecast(lstm_3, val_idx, n_past=n_past)
lstm_3_preds_scaled = scale(scaler_vol, lstm_3_preds)
log_perf(y_val_scaled, lstm_3_preds_scaled,
         f"LSTM 1 layer, 16 units, {len(lstm_3_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, None, 1)           0
#
#  lstm (LSTM)                 (None, 16)                1152
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 10/10 [==============================] - 3s 76ms/step - loss: 1.9853e-04 - rmspe: 0.0099 - val_loss: 1.1300e-04 - val_rmspe: 0.0100
# Epoch 2/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 1.9281e-04 - rmspe: 0.0094 - val_loss: 1.4315e-05 - val_rmspe: 0.0034
# Epoch 3/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 1.5007e-04 - rmspe: 0.0054 - val_loss: 1.8673e-05 - val_rmspe: 0.0037
# Epoch 4/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 1.3462e-04 - rmspe: 0.0065 - val_loss: 3.2709e-05 - val_rmspe: 0.0048
# Epoch 5/1000
# 10/10 [==============================] - 0s 21ms/step - loss:
1000
# 10/10 [==============================] - 0s 22ms/step - loss: 5.0047e-05 - rmspe: 0.0033 - val_loss: 8.6639e-06 - val_rmspe: 0.0023
# Epoch 32/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.9088e-05 - rmspe: 0.0032 - val_loss: 8.6085e-06 - val_rmspe: 0.0023
# Epoch 33/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.8134e-05 - rmspe: 0.0032 - val_loss: 8.5699e-06 - val_rmspe: 0.0023
# Epoch 34/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.7184e-05 - rmspe: 0.0032 - val_loss: 8.5496e-06 - val_rmspe: 0.0023
# Epoch 35/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.6243e-05 - rmspe: 0.0031 - val_loss: 8.5483e-06 - val_rmspe: 0.0023
# Epoch 36/1000
# 10/10 [==============================] - 0s 24ms/step - loss: 4.5314e-05 - rmspe: 0.0031 - val_loss: 8.5658e-06 - val_rmspe: 0.0023
# Epoch 37/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 4.4406e-05 - rmspe: 0.0031 - val_loss: 8.5996e-06 - val_rmspe: 0.0023
# Epoch 38/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.3524e-05 - rmspe: 0.0031 - val_loss: 8.6448e-06 - val_rmspe: 0.0023
# Epoch 39/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.2675e-05 - rmspe: 0.0031 - val_loss: 8.6934e-06 - val_rmspe: 0.0023
# Epoch 40/1000
# 10/10 [==============================] - 0s 23ms/step - loss: 4.1862e-05 - rmspe: 0.0031 - val_loss: 8.7353e-06 - val_rmspe: 0.0023
# Epoch 41/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.1085e-05 - rmspe: 0.0030 - val_loss: 8.7603e-06 - val_rmspe: 0.0024
# Epoch 42/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 4.0342e-05 - rmspe: 0.0030 - val_loss: 8.7600e-06 - val_rmspe: 0.0024
# Epoch 43/1000
# 10/10 [==============================] - 0s 22ms/step - loss: 3.9628e-05 - rmspe: 0.0030 - val_loss: 8.7299e-06 - val_rmspe: 0.0024
# Epoch 44/1000
#  7/10 [====================>.........] - ETA: 0s - loss: 1.7593e-05 - rmspe: 0.0022
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\gabriel\Documents\TCC\volatibilidade\notebooks\nootbook-4-30-dias copy.ipynb Cell 163 in 2
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=22'>23</a> early_stopping_cb = EarlyStopping(patience=100,
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=23'>24</a>                                   restore_best_weights=True,
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=24'>25</a>                                   monitor='val_rmspe')
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=26'>27</a> lstm_3.summary()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=27'>28</a> lstm_3_res = lstm_3.fit(mat_X_train, mat_y_train,
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=28'>29</a>                         callbacks=[early_stopping_cb],
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=29'>30</a>                         validation_split=0.2,
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=30'>31</a>                         shuffle=False,
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=31'>32</a>                         batch_size=batch_size,
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=32'>33</a>                         epochs=1000)
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=33'>34</a> lstm_3_preds = forecast(lstm_3, val_idx, n_past=n_past)
#      <a href='vscode-notebook-cell:/c%3A/Users/gabriel/Documents/TCC/volatibilidade/notebooks/nootbook-4-30-dias%20copy.ipynb#Y323sZmlsZQ%3D%3D?line=34'>35</a> lstm_3_preds_scaled = scale(scaler_vol, lstm_3_preds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 60
batch_size = 64
mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

lstm_4 = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), 
                           input_shape=[None]),                            
    # ADDING 1 LSTM LAYER
    tf.keras.layers.LSTM(32),
    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_4.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])
# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

lstm_4.summary()
lstm_4_res = lstm_4.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, 
                        shuffle=False,
                        batch_size=batch_size, 
                        epochs=1000)
lstm_4_preds = forecast(lstm_4, val_idx, n_past=n_past)
lstm_4_preds_scaled = scale(scaler_vol, lstm_4_preds)
log_perf(y_val_scaled, lstm_4_preds_scaled,
         f"LSTM 1 layer, 32 units, {len(lstm_4_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, None, 1)           0
#
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 10/10 [==============================] - 3s 74ms/step - loss: 1.9461e-04 - rmspe: 0.0095 - val_loss: 1.9484e-05 - val_rmspe: 0.0037
# Epoch 2/1000
# 10/10 [==============================] - 0s 21ms/step - loss: 1.2351e-04 - rmspe: 0.0058 - val_loss: 2.2120e-05 - val_rmspe: 0.0038
# Epoch 3/1000
# 10/10 [==============================] - 0s 22ms/step - loss:
1000
# 10/10 [==============================] - 0s 15ms/step - loss: 2.4658e-05 - rmspe: 0.0024 - val_loss: 4.8776e-06 - val_rmspe: 0.0018
# Epoch 167/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.6552e-05 - rmspe: 0.0024 - val_loss: 5.5704e-06 - val_rmspe: 0.0019
# Epoch 168/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.4841e-05 - rmspe: 0.0024 - val_loss: 4.1337e-06 - val_rmspe: 0.0016
# Epoch 169/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.4107e-05 - rmspe: 0.0023 - val_loss: 5.2446e-06 - val_rmspe: 0.0018
# Epoch 170/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.4564e-05 - rmspe: 0.0024 - val_loss: 4.9537e-06 - val_rmspe: 0.0018
# Epoch 171/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.4886e-05 - rmspe: 0.0024 - val_loss: 5.4046e-06 - val_rmspe: 0.0019
# Epoch 172/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 2.5667e-05 - rmspe: 0.0025 - val_loss: 4.0483e-06 - val_rmspe: 0.0016
# Epoch 173/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.3786e-05 - rmspe: 0.0023 - val_loss: 5.1030e-06 - val_rmspe: 0.0018
# Epoch 174/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.3507e-05 - rmspe: 0.0023 - val_loss: 5.6065e-06 - val_rmspe: 0.0019
# Epoch 175/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 2.3700e-05 - rmspe: 0.0024 - val_loss: 4.1661e-06 - val_rmspe: 0.0016
# Epoch 176/1000
# 10/10 [==============================] - 0s 17ms/step - loss: 2.5523e-05 - rmspe: 0.0024 - val_loss: 5.6368e-06 - val_rmspe: 0.0019
# Epoch 177/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 2.5887e-05 - rmspe: 0.0025 - val_loss: 5.2963e-06 - val_rmspe: 0.0019
# Epoch 178/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 2.3969e-05 - rmspe: 0.0024 - val_loss: 4.6206e-06 - val_rmspe: 0.0017
# Epoch 179/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 2.3638e-05 - rmspe: 0.0023 - val_loss: 4.7425e-06 - val_rmspe: 0.0017
# Epoch 180/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.5354e-05 - rmspe: 0.0025 - val_loss: 5.4825e-06 - val_rmspe: 0.0019
# Epoch 181/1000
# 10/10 [==============================] - 0s 14ms/step - loss: 2.5809e-05 - rmspe: 0.0025 - val_loss: 4.5144e-06 - val_rmspe: 0.0017
# Epoch 182/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 2.3274e-05 - rmspe: 0.0023 - val_loss: 5.2067e-06 - val_rmspe: 0.0018
# 12/12 [==============================] - 0s 3ms/step
#                                                                                   Validation MSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                      0.000650
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                      0.000509
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                      0.000335
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                       0.000539
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                      0.000629
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                      0.000640
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000646
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000792
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000768
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000594
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                      0.000506
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                      0.000526
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                      0.000314
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                      0.000322
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                       0.000345
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                        0.000356
#
#                                                                                   Validation RMSPE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                        0.379012
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                        0.375816
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                        0.435683
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                         0.461694
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                        0.495157
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                        0.519820
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30          1.343903
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30          0.443003
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60          0.576581
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60          0.606077
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                        0.568336
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                        0.612029
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                        0.407303
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                        0.397098
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                         0.685964
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                          0.454812
#
#                                                                                   Validation RMSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.025490
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.022565
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.018316
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.023226
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.025075
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.025294
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.025412
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.028147
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.027713
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.024367
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.022490
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.022943
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.017713
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.017956
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.018570
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.018864
#
#                                                                                   Validation MAPE
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.280628
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.273779
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.246260
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.299151
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.506265
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.320653
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.342430
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.332865
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.345428
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.245153
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.240953
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.297945
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.274187

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 60
batch_size = 64
mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

lstm_7 = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), 
                           input_shape=[None]),                            
    # ADDING 1 LSTM LAYER
    tf.keras.layers.LSTM(16),
    tf.keras.layers.Dropout(0.1),
    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_7.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])
# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

lstm_7.summary()
lstm_7_res = lstm_7.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, 
                        shuffle=False,
                        batch_size=batch_size, 
                        epochs=1000)
lstm_7_preds = forecast(lstm_7, val_idx, n_past=n_past)
lstm_7_preds_scaled = scale(scaler_vol, lstm_7_preds)

log_perf(y_val_scaled, lstm_7_preds_scaled,
         f"LSTM 1 layer, 16 units, Dropout(10%), {len(lstm_7_res.epoch)}/1000 epochs, n_past={n_past}")

tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 60
batch_size = 64
mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

lstm_8 = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), 
                           input_shape=[None]),                            
    # ADDING 1 LSTM LAYER
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dropout(0.1),
    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_8.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])
# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

lstm_8.summary()
lstm_8_res = lstm_8.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, 
                        shuffle=False,
                        batch_size=batch_size, 
                        epochs=1000)
lstm_8_preds = forecast(lstm_8, val_idx, n_past=n_past)
lstm_8_preds_scaled = scale(scaler_vol, lstm_8_preds)
log_perf(y_val_scaled, lstm_8_preds_scaled,
         f"LSTM 1 layer, 32 units, Dropout(10%), {len(lstm_8_res.epoch)}/1000 epochs, n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, None, 1)           0
#
#  lstm (LSTM)                 (None, 16)                1152
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 10/10 [==============================] - 3s 73ms/step - loss: 1.2982e-04 - rmspe: 0.0069 - val_loss: 1.2434e-05 - val_rmspe: 0.0030
# Epoch 2/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 8.9367e-05 - rmspe: 0.0059 - val_loss: 7.6232e-06 - val_rmspe: 0.0024
# Epoch 3/1000
# 10/10 [==============================] - 0s 18ms/step - loss: 7.5804e-05 - rmspe: 0.0040 - val_loss: 1.9739e-05 - val_rmspe: 0.0037
# Epoch 4/1000
# 10/10 [==============================] - 0s 18ms/step - loss:
1000
# 10/10 [==============================] - 0s 48ms/step - loss: 3.8492e-05 - rmspe: 0.0033 - val_loss: 1.3962e-05 - val_rmspe: 0.0033
# Epoch 52/1000
# 10/10 [==============================] - 0s 50ms/step - loss: 3.3504e-05 - rmspe: 0.0033 - val_loss: 1.1697e-05 - val_rmspe: 0.0030
# Epoch 53/1000
# 10/10 [==============================] - 0s 47ms/step - loss: 3.8100e-05 - rmspe: 0.0034 - val_loss: 1.7388e-05 - val_rmspe: 0.0038
# Epoch 54/1000
# 10/10 [==============================] - 0s 48ms/step - loss: 3.3837e-05 - rmspe: 0.0035 - val_loss: 1.0651e-05 - val_rmspe: 0.0028
# Epoch 55/1000
# 10/10 [==============================] - 0s 48ms/step - loss: 3.2607e-05 - rmspe: 0.0033 - val_loss: 8.2326e-06 - val_rmspe: 0.0025
# Epoch 56/1000
# 10/10 [==============================] - 0s 49ms/step - loss: 3.1635e-05 - rmspe: 0.0031 - val_loss: 9.8229e-06 - val_rmspe: 0.0027
# Epoch 57/1000
# 10/10 [==============================] - 1s 52ms/step - loss: 3.2617e-05 - rmspe: 0.0032 - val_loss: 7.7432e-06 - val_rmspe: 0.0024
# Epoch 58/1000
# 10/10 [==============================] - 0s 49ms/step - loss: 3.2922e-05 - rmspe: 0.0031 - val_loss: 1.0476e-05 - val_rmspe: 0.0028
# Epoch 59/1000
# 10/10 [==============================] - 0s 49ms/step - loss: 3.2525e-05 - rmspe: 0.0032 - val_loss: 8.6549e-06 - val_rmspe: 0.0025
# Epoch 60/1000
# 10/10 [==============================] - 0s 50ms/step - loss: 3.1695e-05 - rmspe: 0.0031 - val_loss: 1.0801e-05 - val_rmspe: 0.0029
# Epoch 61/1000
# 10/10 [==============================] - 0s 49ms/step - loss: 3.1832e-05 - rmspe: 0.0031 - val_loss: 9.9726e-06 - val_rmspe: 0.0027
# Epoch 62/1000
# 10/10 [==============================] - 0s 48ms/step - loss: 3.1644e-05 - rmspe: 0.0032 - val_loss: 1.1995e-05 - val_rmspe: 0.0030
# Epoch 63/1000
# 10/10 [==============================] - 0s 45ms/step - loss: 3.1262e-05 - rmspe: 0.0033 - val_loss: 1.0603e-05 - val_rmspe: 0.0028
# Epoch 64/1000
# 10/10 [==============================] - 0s 47ms/step - loss: 3.1090e-05 - rmspe: 0.0032 - val_loss: 1.0215e-05 - val_rmspe: 0.0028
# 12/12 [==============================] - 2s 12ms/step
#                                                                                   Validation MSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                      0.000650
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                      0.000509
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                      0.000335
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                       0.000539
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                      0.000629
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                      0.000640
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000646
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000792
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000768
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000594
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                      0.000506
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                      0.000526
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                      0.000314
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                      0.000322
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                       0.000345
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                        0.000356
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                         0.000375
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                         0.000462
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                        0.000297
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                         0.000371
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                      0.000627
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                       0.000558
#
#                                                                                   Validation RMSPE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                        0.379012
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                        0.375816
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                        0.435683
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                         0.461694
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                        0.495157
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                        0.519820
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30          1.343903
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30          0.443003
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60          0.576581
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60          0.606077
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                        0.568336
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                        0.612029
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                        0.407303
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                        0.397098
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                         0.685964
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                          0.454812
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                           0.564730
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                           0.768443
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                          0.705142
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                           0.505510
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                        1.076740
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                         0.840556
#
#                                                                                   Validation RMSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.025490
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.022565
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.018316
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.023226
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.025075
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.025294
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.025412
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.028147
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.027713
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.024367
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.022490
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.022943
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.017713
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.017956
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.018570
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.018864
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                          0.019374
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.021490
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                         0.017224
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                          0.019274
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.025041
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.023613
#
#                                                                                   Validation MAPE
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.280628
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.273779
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.246260
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.299151
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.506265
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.320653
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.342430
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.332865
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.345428
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.245153
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.240953
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.297945
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.274187
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                          0.294005
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.344790
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                         0.273765
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                          0.280309
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.444688
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.389031

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 30
batch_size = 64
mat_X_train, mat_y_train = windowed_dataset(x_train, y_train, n_past)

lstm_14 = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), 
                           input_shape=[None]),                            
    # ADDING 1 LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    # ADDING 2nd BIDIRECTIONAL LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dropout(0.2),
    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_14.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])


# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

lstm_14.summary()
lstm_14_res = lstm_14.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, 
                        shuffle=False,
                        batch_size=batch_size, 
                        epochs=1000)
lstm_14_preds = forecast(lstm_14, val_idx, n_past=n_past)
lstm_14_preds_scaled = scale(scaler_vol, lstm_14_preds)
log_perf(y_val_scaled, lstm_14_preds_scaled, 
         f"2 layers Bidirect LSTM (32/16 units), {len(lstm_14_res.epoch)},Droupout(10%), n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, None, 1)           0
#
#  bidirectional (Bidirectiona  (None, None, 64)         8704
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 32)               10368
#  nal)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 19,105
# Trainable params: 19,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 10/10 [==============================] - 9s 202ms/step - loss: 2.8411e-04 - rmspe: 0.0106 - val_loss: 1.3303e-05 - val_rmspe: 0.0032
# Epoch 2/1000
# 10/10 [==============================] - 0s 26ms/step - loss: 1.5861e-04 - rmspe: 0.0081 - val_loss: 2.4250e-05 - val_rmspe: 0.0040
# Epoch 3/1000
# 10/10 [==============================] - 0s 27ms/step - loss: 1.3653e-04 - rmspe: 0.0054 - val_loss: 1.8841e-05 - val_rmspe: 0.0036
# Epoch 4/1000
# 10/10 [==============================] - 0s 28ms/step - loss:
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.024367
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.021490
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.022943
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.023613
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.025041
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.025412
#
#                                                                                   Validation MAPE
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.240953
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.245153
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.246260
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                         0.273765
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.273779
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.274187
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                          0.280309
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.280628
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                          0.294005
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.297945
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.299151
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.320653
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.332865
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                       0.333218
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.342430
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.344790
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.345428
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.389031
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.444688
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.506265

# %%
perf_df.sort_values(by='Validation RMSE', ascending=True)
# Out:
#                                                                                   Validation MSE  \
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                        0.000297
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                      0.000314
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                      0.000322
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                      0.000335
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                       0.000345
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                        0.000356
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                         0.000371
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                         0.000375
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                         0.000462
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                      0.000466
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                      0.000506
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                      0.000509
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                      0.000526
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                       0.000539
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                       0.000558
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000594
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                      0.000627
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                      0.000629
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                      0.000640
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000646
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                      0.000650
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000768
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000792
#
#                                                                                   Validation RMSPE  \
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                          0.705142
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                        0.407303
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                        0.397098
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                        0.435683
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                         0.685964
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                          0.454812
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                           0.505510
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                           0.564730
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                           0.768443
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                        0.633264
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                        0.568336
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                        0.375816
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                        0.612029
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                         0.461694
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                         0.840556
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60          0.606077
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                        1.076740
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                        0.495157
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                        0.519820
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30          1.343903
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                        0.379012
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60          0.576581
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30          0.443003
#
#                                                                                   Validation RMSE  \
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                         0.017224
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.017713
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.017956
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.018316
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.018570
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.018864
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                          0.019274
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                          0.019374
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.021490
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                       0.021585
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.022490
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.022565
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.022943
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.023226
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.023613
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.024367
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.025041
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.025075
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.025294
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.025412
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.025490
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.027713
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.028147
#
#                                                                                   Validation MAPE
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                         0.273765
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.245153
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.240953
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.246260
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.297945
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.274187
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                          0.280309
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                          0.294005
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.344790
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                       0.333218
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.332865
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.273779
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.345428
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.299151
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.389031
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.342430
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.444688
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.506265
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.280628
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.320653

# %%
perf_df.sort_values(by='Validation MSE', ascending=True)
# Out:
#                                                                                   Validation MSE  \
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                        0.000297
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                      0.000314
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                      0.000322
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                      0.000335
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                       0.000345
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                        0.000356
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                         0.000371
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                         0.000375
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                         0.000462
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                      0.000466
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                      0.000506
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                      0.000509
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                      0.000526
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                       0.000539
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                       0.000558
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000594
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                      0.000627
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                      0.000629
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                      0.000640
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000646
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                      0.000650
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60        0.000768
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30        0.000792
#
#                                                                                   Validation RMSPE  \
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                          0.705142
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                        0.407303
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                        0.397098
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                        0.435683
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                         0.685964
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                          0.454812
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                           0.505510
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                           0.564730
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                           0.768443
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                        0.633264
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                        0.568336
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                        0.375816
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                        0.612029
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                         0.461694
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                         0.840556
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60          0.606077
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                        1.076740
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                        0.495157
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                        0.519820
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30          1.343903
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                        0.379012
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60          0.576581
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30          0.443003
#
#                                                                                   Validation RMSE  \
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                         0.017224
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.017713
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.017956
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.018316
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.018570
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.018864
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                          0.019274
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                          0.019374
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.021490
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                       0.021585
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.022490
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.022565
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.022943
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.023226
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.023613
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.024367
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.025041
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.025075
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.025294
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.025412
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.025490
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.027713
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.028147
#
#                                                                                   Validation MAPE
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                         0.273765
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                       0.245153
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                       0.240953
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                       0.246260
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                        0.297945
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                         0.274187
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                          0.280309
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                          0.294005
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                          0.344790
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                       0.333218
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                       0.332865
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                       0.273779
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                       0.345428
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                        0.299151
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                        0.389031
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60         0.342430
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                       0.444688
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                       0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                       0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30         0.506265
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                       0.280628
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60         0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30         0.320653

# %% [markdown]
# ### LSTM Multivariate

# %%
df['retuns_squared'] = df['returns']**2

# %%
features = ['returns', 'retuns_squared', 'vol_current', 'garch11_student', 'covid']
# PLOT EACH NUMERICAL COLUMN
with sns.axes_style("darkgrid"):
    fig, axes = plt.subplots(nrows=len(features), ncols=2, figsize=(15,20))

    for i, c in enumerate(features):
        ax1, ax2 = axes[i][0], axes[i][1]
        ax1.plot(df[c])
        ax1.set_title(c)

        sns.distplot(df[c], ax=ax2)

    plt.tight_layout()
    # plt.savefig(os.path.join(directory_to_img, 'features.png'), 
    #             dpi=300, bbox_inches='tight')
    plt.show();

# %%
# SEPARATE INPUT DATAFRAME FROM df
input_df = df[features]

# SEPARATE INPUTS FOR TRAINING SET ONLY
X_train = input_df.loc[train_idx]

# %%
def forecast_multi(model, range_idx):
    location_index = df.vol_current.index.get_loc(range_idx[0])
    end_idx = range_idx[-1]
    start_idx = df.vol_current.iloc[location_index - n_past + 1:].index[0]
    mat_X, _ = windowed_dataset(input_df[start_idx:end_idx], 
                                df.vol_future[range_idx], n_past)
    preds = pd.Series(model.predict(mat_X)[:, 0],
                      index=range_idx)

    return preds

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 30
batch_size = 64
n_dims = input_df.shape[1]

mat_X_train, mat_y_train = windowed_dataset(X_train, y_train, n_past)

# CONSTRUCTING MULTIVARIATE BIDIRECTIONAL LSTM NN
lstm_multi_1 = tf.keras.models.Sequential([ 
    tf.keras.layers.InputLayer(input_shape=[n_past, n_dims]),
    # BATCH NORMALIZATION
    tf.keras.layers.BatchNormalization(), 
    # ADDING 1st LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.1),
    # ADDING 2nd LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dropout(0.1),

    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_multi_1.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])

checkpoint_cb = ModelCheckpoint('lstm_multi_1.h5',
                                save_best_only=True,
                                monitor='val_rmspe')

# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

print(lstm_multi_1.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 30, 5)            20
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 30, 64)           9728
#  l)
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  bidirectional_1 (Bidirectio  (None, 32)               10368
#  nal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 20,149
# Trainable params: 20,139
# Non-trainable params: 10
# _________________________________________________________________
# None

# %%
# FITTING TO TRAINING DATA
lstm_multi_1_res = lstm_multi_1.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, shuffle=True,
                        verbose=0, batch_size=batch_size, epochs=1000)

# %%
viz_train_val_metrics(lstm_multi_1_res)
# FORECASTING ON VALIDATION SET
lstm_multi_1_preds = forecast_multi(lstm_multi_1, val_idx)

# SCALING OUTPUT TO MINMAXSCALER FITTED TO TRAINING CURRENT VOLUME
lstm_multi_1_preds_scaled = scale(scaler_vol, lstm_multi_1_preds)
# Out:
# 12/12 [==============================] - 2s 12ms/step

# %%
# PLOTTING PREDICTIONS VS. TARGET VALUES ON VALIDATION SET
viz_model(y_val_scaled, lstm_multi_1_preds_scaled, 
          f"Multivariate 2 Bidirect LSTM layers (32/16 units), {n_past} days look back")

# %%
log_perf(y_val_scaled, lstm_multi_1_preds_scaled,
         f"Multivariate Bidirect LSTM 2 layers (32/16 units), n_past={n_past}")
# Out:
#                                                                     Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30        0.000378
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30        0.000527
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30              0.000442
#
#                                                                     Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30          0.650405
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30          0.419211
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30                0.394307
#
#                                                                     Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30         0.019431
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30         0.022946
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30               0.021035
#
#                                                                     Validation MAPE
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30         0.280260
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30         0.290597
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30               0.260153

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 30
batch_size = 64
n_dims = input_df.shape[1]

mat_X_train, mat_y_train = windowed_dataset(X_train, y_train, n_past)

# CONSTRUCTING MULTIVARIATE BIDIRECTIONAL LSTM NN
lstm_multi_2 = tf.keras.models.Sequential([ 
    tf.keras.layers.InputLayer(input_shape=[n_past, n_dims]),
    # BATCH NORMALIZATION
    tf.keras.layers.BatchNormalization(), 
    # ADDING 1st LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.1),
    # ADDING 2nd LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dropout(0.1),

    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_multi_2.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])

checkpoint_cb = ModelCheckpoint('lstm_multi_2.h5',
                                save_best_only=True,
                                monitor='val_rmspe')

# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

print(lstm_multi_2.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 30, 5)            20
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 30, 64)           9728
#  l)
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  bidirectional_1 (Bidirectio  (None, 32)               10368
#  nal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 20,149
# Trainable params: 20,139
# Non-trainable params: 10
# _________________________________________________________________
# None

# %%
# FITTING TO TRAINING DATA
lstm_multi_2_res = lstm_multi_2.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, shuffle=True,
                        verbose=0, batch_size=batch_size, epochs=1000)

# %%
lstm_multi_2_preds = forecast_multi(lstm_multi_2, val_idx)
# SCALING OUTPUT TO MINMAXSCALER FITTED TO TRAINING CURRENT VOLUME
lstm_multi_2_preds_scaled = scale(scaler_vol, lstm_multi_2_preds)
log_perf(y_val_scaled, lstm_multi_2_preds_scaled,
         f"Multivariate Bidirect LSTM 2 layers (32/16 units), {len(lstm_multi_2_res.epoch)} epochs, Dropout(10%) n_past={n_past}")
# Out:
# 12/12 [==============================] - 2s 12ms/step
#                                                                                        Validation MSE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30                           0.000378
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30                           0.000527
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30                                 0.000442
# Multivariate Bidirect LSTM 2 layers (32/16 units), 195 epochs, Dropout(10%) n_past=30        0.000357
#
#                                                                                        Validation RMSPE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30                             0.650405
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30                             0.419211
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30                                   0.394307
# Multivariate Bidirect LSTM 2 layers (32/16 units), 195 epochs, Dropout(10%) n_past=30          0.344389
#
#                                                                                        Validation RMSE  \
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30                            0.019431
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30                            0.022946
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30                                  0.021035
# Multivariate Bidirect LSTM 2 layers (32/16 units), 195 epochs, Dropout(10%) n_past=30         0.018903
#
#                                                                                        Validation MAPE
# Simple LR Fully Connected NN, 16 units, 476/1000 epochs, n_past=30                            0.280260
# Simple LR Fully Connected NN, 16 units, 175/1000 epochs, n_past=30                            0.290597
# Multivariate Bidirect LSTM 2 layers (32/16 units), n_past=30                                  0.260153
# Multivariate Bidirect LSTM 2 layers (32/16 units), 195 epochs, Dropout(10%) n_past=30         0.237756

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 30
batch_size = 64
n_dims = input_df.shape[1]

mat_X_train, mat_y_train = windowed_dataset(X_train, y_train, n_past)

# CONSTRUCTING MULTIVARIATE BIDIRECTIONAL LSTM NN
lstm_multi_3 = tf.keras.models.Sequential([ 
    tf.keras.layers.InputLayer(input_shape=[n_past, n_dims]),
    # BATCH NORMALIZATION
    tf.keras.layers.BatchNormalization(), 
    # ADDING 1st LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True)),
    tf.keras.layers.Dropout(0.1),
    # ADDING 2nd LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dropout(0.1),

    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_multi_3.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])

# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

print(lstm_multi_3.summary())

# FITTING TO TRAINING DATA
lstm_multi_3_res = lstm_multi_3.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, shuffle=True,
                        verbose=0, batch_size=batch_size, epochs=1000)

lstm_multi_3_preds = forecast_multi(lstm_multi_3, val_idx)
# SCALING OUTPUT TO MINMAXSCALER FITTED TO TRAINING CURRENT VOLUME
lstm_multi_3_preds_scaled = scale(scaler_vol, lstm_multi_3_preds)
log_perf(y_val_scaled, lstm_multi_3_preds_scaled,
         f"Multivariate Bidirect LSTM 2 layers (16/16 units), {len(lstm_multi_3_res.epoch)} epochs, Dropout(10%) n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 30, 5)            20
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 30, 32)           2816
#  l)
#
#  dropout (Dropout)           (None, 30, 32)            0
#
#  bidirectional_1 (Bidirectio  (None, 32)               6272
#  nal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 9,141
# Trainable params: 9,131
# Non-trainable params: 10
# _________________________________________________________________
# None

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 30
batch_size = 64
n_dims = input_df.shape[1]

mat_X_train, mat_y_train = windowed_dataset(X_train, y_train, n_past)

# CONSTRUCTING MULTIVARIATE BIDIRECTIONAL LSTM NN
lstm_multi_4 = tf.keras.models.Sequential([ 
    tf.keras.layers.InputLayer(input_shape=[n_past, n_dims]),
    # BATCH NORMALIZATION
    tf.keras.layers.BatchNormalization(), 
    # ADDING 1st LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True)),
    tf.keras.layers.Dropout(0.1),
    # ADDING 2nd LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dropout(0.1),

    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_multi_4.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])

# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

print(lstm_multi_4.summary())

# FITTING TO TRAINING DATA
lstm_multi_4_res = lstm_multi_4.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, shuffle=True,
                        verbose=0, batch_size=batch_size, epochs=1000)

lstm_multi_4_preds = forecast_multi(lstm_multi_4, val_idx)
# SCALING OUTPUT TO MINMAXSCALER FITTED TO TRAINING CURRENT VOLUME
lstm_multi_4_preds_scaled = scale(scaler_vol, lstm_multi_4_preds)
log_perf(y_val_scaled, lstm_multi_4_preds_scaled,
         f"Multivariate Bidirect LSTM 2 layers (16/16 units), {len(lstm_multi_4_res.epoch)} epochs, Dropout(10%) n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 30, 5)            20
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 30, 32)           2816
#  l)
#
#  dropout (Dropout)           (None, 30, 32)            0
#
#  bidirectional_1 (Bidirectio  (None, 32)               6272
#  nal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 9,141
# Trainable params: 9,131
# Non-trainable params: 10
# _________________________________________________________________
# None
# 12/12 [==============================] - 1s 6ms/step
#                                                                                        Validation MSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                           0.000650
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                           0.000509
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                           0.000335
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                            0.000539
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                           0.000629
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                           0.000640
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30             0.000646
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30             0.000792
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60             0.000768
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60             0.000594
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                           0.000506
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                           0.000526
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                           0.000314
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                           0.000322
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                            0.000345
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                             0.000356
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                              0.000375
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                              0.000462
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                             0.000297
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                              0.000371
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                           0.000627
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                            0.000558
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                           0.000466
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                              0.000455
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30         0.002671
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30        0.000339
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30        0.000517
#
#                                                                                        Validation RMSPE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                             0.379012
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                             0.375816
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                             0.435683
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                              0.461694
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                             0.495157
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                             0.519820
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30               1.343903
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30               0.443003
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60               0.576581
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60               0.606077
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                             0.568336
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                             0.612029
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                             0.407303
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                             0.397098
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                              0.685964
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                               0.454812
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                                0.564730
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                                0.768443
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                               0.705142
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                                0.505510
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                             1.076740
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                              0.840556
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                             0.633264
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                                0.311984
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30           1.074631
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30          0.512260
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30          0.986647
#
#                                                                                        Validation RMSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                            0.025490
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                            0.022565
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                            0.018316
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                             0.023226
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                            0.025075
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                            0.025294
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30              0.025412
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30              0.028147
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60              0.027713
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60              0.024367
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                            0.022490
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                            0.022943
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                            0.017713
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                            0.017956
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                             0.018570
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                              0.018864
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                               0.019374
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                               0.021490
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                              0.017224
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                               0.019274
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                            0.025041
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                             0.023613
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                            0.021585
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                               0.021333
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30          0.051678
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30         0.018400
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30         0.022745
#
#                                                                                        Validation MAPE
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                            0.280628
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                            0.273779
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                            0.246260
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                             0.299151
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                            0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                            0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30              0.506265
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30              0.320653
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60              0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60              0.342430
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                            0.332865
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                            0.345428
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                            0.245153
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                            0.240953
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                             0.297945
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                              0.274187
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                               0.294005
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                               0.344790
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                              0.273765
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                               0.280309
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                            0.444688
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                             0.389031
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                            0.333218
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                               0.232898
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30          0.679871
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30         0.268521
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30         0.359661

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 60
batch_size = 64
n_dims = input_df.shape[1]

mat_X_train, mat_y_train = windowed_dataset(X_train, y_train, n_past)

# CONSTRUCTING MULTIVARIATE BIDIRECTIONAL LSTM NN
lstm_multi_5 = tf.keras.models.Sequential([ 
    tf.keras.layers.InputLayer(input_shape=[n_past, n_dims]),
    # BATCH NORMALIZATION
    tf.keras.layers.BatchNormalization(), 
    # ADDING 1st LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Dropout(0.1),
    # ADDING 2nd LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dropout(0.1),

    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_multi_5.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])

# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

print(lstm_multi_5.summary())

# FITTING TO TRAINING DATA
lstm_multi_5_res = lstm_multi_5.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, shuffle=True,
                        verbose=0, batch_size=batch_size, epochs=1000)

lstm_multi_5_preds = forecast_multi(lstm_multi_5, val_idx)
# SCALING OUTPUT TO MINMAXSCALER FITTED TO TRAINING CURRENT VOLUME
lstm_multi_5_preds_scaled = scale(scaler_vol, lstm_multi_5_preds)
log_perf(y_val_scaled, lstm_multi_5_preds_scaled,
         f"Multivariate Bidirect LSTM 2 layers (32/16 units), {len(lstm_multi_5_res.epoch)} epochs, Dropout(10%) n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 60, 5)            20
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 60, 64)           9728
#  l)
#
#  dropout (Dropout)           (None, 60, 64)            0
#
#  bidirectional_1 (Bidirectio  (None, 32)               10368
#  nal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 20,149
# Trainable params: 20,139
# Non-trainable params: 10
# _________________________________________________________________
# None
# 12/12 [==============================] - 2s 14ms/step
#                                                                                        Validation MSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                           0.000650
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                           0.000509
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                           0.000335
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                            0.000539
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                           0.000629
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                           0.000640
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30             0.000646
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30             0.000792
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60             0.000768
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60             0.000594
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                           0.000506
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                           0.000526
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                           0.000314
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                           0.000322
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                            0.000345
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                             0.000356
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                              0.000375
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                              0.000462
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                             0.000297
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                              0.000371
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                           0.000627
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                            0.000558
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                           0.000466
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                              0.000455
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30         0.002671
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30        0.000339
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30        0.000517
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60         0.001667
#
#                                                                                        Validation RMSPE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                             0.379012
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                             0.375816
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                             0.435683
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                              0.461694
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                             0.495157
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                             0.519820
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30               1.343903
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30               0.443003
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60               0.576581
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60               0.606077
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                             0.568336
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                             0.612029
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                             0.407303
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                             0.397098
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                              0.685964
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                               0.454812
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                                0.564730
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                                0.768443
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                               0.705142
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                                0.505510
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                             1.076740
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                              0.840556
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                             0.633264
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                                0.311984
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30           1.074631
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30          0.512260
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30          0.986647
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60           2.018030
#
#                                                                                        Validation RMSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                            0.025490
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                            0.022565
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                            0.018316
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                             0.023226
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                            0.025075
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                            0.025294
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30              0.025412
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30              0.028147
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60              0.027713
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60              0.024367
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                            0.022490
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                            0.022943
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                            0.017713
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                            0.017956
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                             0.018570
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                              0.018864
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                               0.019374
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                               0.021490
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                              0.017224
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                               0.019274
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                            0.025041
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                             0.023613
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                            0.021585
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                               0.021333
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30          0.051678
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30         0.018400
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30         0.022745
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60          0.040831
#
#                                                                                        Validation MAPE
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                            0.280628
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                            0.273779
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                            0.246260
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                             0.299151
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                            0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                            0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30              0.506265
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30              0.320653
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60              0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60              0.342430
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                            0.332865
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                            0.345428
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                            0.245153
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                            0.240953
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                             0.297945
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                              0.274187
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                               0.294005
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                               0.344790
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                              0.273765
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                               0.280309
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                            0.444688
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                             0.389031
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                            0.333218
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                               0.232898
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30          0.679871
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30         0.268521
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30         0.359661
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60          0.758886

# %%
tf.keras.backend.clear_session()

# SET SEED FOR REPRODUCIBILITY
np.random.seed(seed)

n_past = 60
batch_size = 64
n_dims = input_df.shape[1]

mat_X_train, mat_y_train = windowed_dataset(X_train, y_train, n_past)

# CONSTRUCTING MULTIVARIATE BIDIRECTIONAL LSTM NN
lstm_multi_6 = tf.keras.models.Sequential([ 
    tf.keras.layers.InputLayer(input_shape=[n_past, n_dims]),
    # BATCH NORMALIZATION
    tf.keras.layers.BatchNormalization(), 
    # ADDING 1st LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True)),
    tf.keras.layers.Dropout(0.1),
    # ADDING 2nd LSTM LAYER
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dropout(0.1),

    # DENSE OUTPUT LAYER
    tf.keras.layers.Dense(1)
])

lstm_multi_6.compile(loss='mse', 
               optimizer="adam", 
               metrics=[rmspe])

# STOPPING THE TRAINING IF VALIDATION RMSPE IS NOT IMPROVING 
early_stopping_cb = EarlyStopping(patience=50,
                                  restore_best_weights=True,
                                  monitor='val_rmspe')

print(lstm_multi_6.summary())

# FITTING TO TRAINING DATA
lstm_multi_6_res = lstm_multi_6.fit(mat_X_train, mat_y_train, 
                        callbacks=[early_stopping_cb],
                        validation_split=0.2, shuffle=True,
                        verbose=0, batch_size=batch_size, epochs=1000)

lstm_multi_6_preds = forecast_multi(lstm_multi_6, val_idx)
# SCALING OUTPUT TO MINMAXSCALER FITTED TO TRAINING CURRENT VOLUME
lstm_multi_6_preds_scaled = scale(scaler_vol, lstm_multi_6_preds)
log_perf(y_val_scaled, lstm_multi_6_preds_scaled,
         f"Multivariate Bidirect LSTM 2 layers (16/16 units), {len(lstm_multi_6_res.epoch)} epochs, Dropout(10%) n_past={n_past}")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 60, 5)            20
#  ormalization)
#
#  bidirectional (Bidirectiona  (None, 60, 32)           2816
#  l)
#
#  dropout (Dropout)           (None, 60, 32)            0
#
#  bidirectional_1 (Bidirectio  (None, 32)               6272
#  nal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 9,141
# Trainable params: 9,131
# Non-trainable params: 10
# _________________________________________________________________
# None
# 12/12 [==============================] - 2s 11ms/step
#                                                                                        Validation MSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                           0.000650
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                           0.000509
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                           0.000335
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                            0.000539
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                           0.000629
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                           0.000640
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30             0.000646
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30             0.000792
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60             0.000768
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60             0.000594
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                           0.000506
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                           0.000526
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                           0.000314
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                           0.000322
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                            0.000345
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                             0.000356
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                              0.000375
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                              0.000462
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                             0.000297
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                              0.000371
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                           0.000627
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                            0.000558
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                           0.000466
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                              0.000455
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30         0.002671
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30        0.000339
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30        0.000517
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60         0.001667
# Multivariate Bidirect LSTM 2 layers (16/16 units), 65 epochs, Dropout(10%) n_past=60         0.003435
#
#                                                                                        Validation RMSPE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                             0.379012
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                             0.375816
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                             0.435683
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                              0.461694
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                             0.495157
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                             0.519820
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30               1.343903
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30               0.443003
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60               0.576581
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60               0.606077
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                             0.568336
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                             0.612029
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                             0.407303
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                             0.397098
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                              0.685964
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                               0.454812
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                                0.564730
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                                0.768443
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                               0.705142
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                                0.505510
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                             1.076740
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                              0.840556
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                             0.633264
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                                0.311984
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30           1.074631
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30          0.512260
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30          0.986647
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60           2.018030
# Multivariate Bidirect LSTM 2 layers (16/16 units), 65 epochs, Dropout(10%) n_past=60           0.992524
#
#                                                                                        Validation RMSE  \
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                            0.025490
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                            0.022565
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                            0.018316
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                             0.023226
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                            0.025075
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                            0.025294
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30              0.025412
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30              0.028147
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60              0.027713
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60              0.024367
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                            0.022490
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                            0.022943
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                            0.017713
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                            0.017956
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                             0.018570
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                              0.018864
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                               0.019374
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                               0.021490
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                              0.017224
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                               0.019274
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                            0.025041
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                             0.023613
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                            0.021585
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                               0.021333
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30          0.051678
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30         0.018400
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30         0.022745
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60          0.040831
# Multivariate Bidirect LSTM 2 layers (16/16 units), 65 epochs, Dropout(10%) n_past=60          0.058606
#
#                                                                                        Validation MAPE
# Simple LR Fully Connected NN, 30 units, 182/1000 epochs, n_past=30                            0.280628
# Simple LR Fully Connected NN, 50 units, 135/1000 epochs, n_past=30                            0.273779
# Simple LR Fully Connected NN, 16 units, 282/1000 epochs, n_past=30                            0.246260
# Simple LR Fully Connected NN, 32 units, 92/1000 epochs, n_past=30                             0.299151
# Simple LR Fully Connected NN, 16 units, 311/1000 epochs, n_past=60                            0.303444
# Simple LR Fully Connected NN, 32 units, 316/1000 epochs, n_past=60                            0.316908
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=30              0.506265
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=30              0.320653
# Simple LR Fully Connected NN, 16 units, Dropout (10%) 316/1000 epochs, n_past=60              0.318537
# Simple LR Fully Connected NN, 32 units, Dropout (10%) 316/1000 epochs, n_past=60              0.342430
# LSTM 1 layer, 16 units, 200/1000 epochs, n_past=30                                            0.332865
# LSTM 1 layer, 32 units, 207/1000 epochs, n_past=30                                            0.345428
# LSTM 1 layer, 16 units, 201/1000 epochs, n_past=60                                            0.245153
# LSTM 1 layer, 32 units, 142/1000 epochs, n_past=60                                            0.240953
# LSTM 1 layer, 16 units, 92/1000 epochs, n_past=30                                             0.297945
# LSTM 1 layer, 32 units, Dropout(10%), 182/1000 epochs, n_past=30                              0.274187
# LSTM 1 layer, 16 units, Dropout(10%), 98/1000 epochs, n_past=60                               0.294005
# LSTM 1 layer, 32 units, Dropout(10%), 59/1000 epochs, n_past=60                               0.344790
# 2 layers Bidirect LSTM (32/16 units), 59/1000 epochs,  n_past=30                              0.273765
# 2 layers Bidirect LSTM (32/16 units), 74/1000 epochs, n_past=60                               0.280309
# 2 layers Bidirect LSTM (32/16 units), 54, Dropout (10%), n_past=30                            0.444688
# 2 layers Bidirect LSTM (32/16 units), 64,Droupout(10%), n_past=60                             0.389031
# 2 layers Bidirect LSTM (32/16 units), 103,Droupout(10%), n_past=30                            0.333218
# Multivariate Bidirect LSTM 2 layers (32/16 units) v3, n_past=30                               0.232898
# Multivariate Bidirect LSTM 2 layers (32/16 units), 47 epochs, Dropout(10%) n_past=30          0.679871
# Multivariate Bidirect LSTM 2 layers (16/16 units), 167 epochs, Dropout(10%) n_past=30         0.268521
# Multivariate Bidirect LSTM 2 layers (16/16 units), 144 epochs, Dropout(10%) n_past=30         0.359661
# Multivariate Bidirect LSTM 2 layers (32/16 units), 53 epochs, Dropout(10%) n_past=60          0.758886
# Multivariate Bidirect LSTM 2 layers (16/16 units), 65 epochs, Dropout(10%) n_past=60          0.695952
